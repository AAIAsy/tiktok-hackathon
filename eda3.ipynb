# %%
import pandas as pd
import numpy as np
import re
import ast

def analyze_specific_example():
    """Analyze the specific gmap_id example you provided"""
    
    # The specific example data
    gmap_id = "0x872b46a9afb11747:0xbab4f9c1c4625e5e"
    name = "jay Jaysam2415"
    rating = 1
    resp_raw = "{'text': 'Jay, we strive to provide excellent service to our customers. We do not show that we have ever done business with you and you have never been a customer at our shop. I do see that you have recently reviewed 3 other transmission shops around the valley. We would appreciate the opportunity to clear up any misunderstandings and ask that you please contact our shop at your convenience.', 'time': 1559153757964.0}"
    text = "All I can say is SMH about this place be careful"
    business_category = "Transmission shop, Auto machine shop, Auto repair shop, Auto tune up service, Brake shop, Car repair and maintenance"
    
    print("="*80)
    print("SPECIFIC EXAMPLE ANALYSIS")
    print("="*80)
    
    print(f"GMAP_ID: {gmap_id}")
    print(f"REVIEWER NAME: {name}")
    print(f"RATING: {rating}")
    print(f"REVIEW TEXT: {text}")
    print(f"BUSINESS CATEGORY: {business_category}")
    
    # Parse business response
    try:
        resp_dict = ast.literal_eval(resp_raw)
        business_response = resp_dict.get('text', '')
    except:
        business_response = ""
    
    print(f"BUSINESS RESPONSE: {business_response}")
    
    print(f"\n" + "-"*60)
    print("ANALYSIS BREAKDOWN:")
    print("-"*60)
    
    # Run analysis using the main functions
    analysis = analyze_single_review(text, "Unknown", business_category, rating, True, resp_raw)
    
    print(f"Review Length: {len(text)} characters")
    print(f"Rating: {rating}/5 (negative)")
    print(f"Has Business Response: Yes")
    
    print(f"\nDetailed Pattern Analysis:")
    print(f"- Advertisement patterns: {has_advertisement_patterns(text)}")
    print(f"- Irrelevant content patterns: {has_irrelevant_patterns(text, business_category)}")
    print(f"- Rant without visit patterns: {has_rant_no_visit_patterns(text, rating, True, business_response)}")
    print(f"- Is clean review: {is_actually_clean_review(text, business_category, business_response)}")
    
    print(f"\nFINAL PREDICTED LABEL:")
    print(f"Suggested Label: {analysis['suggested_label']}")
    print(f"Confidence: {analysis['confidence']}")
    print(f"Reasoning: {analysis['reason']}")
    
    print(f"\nKEY EVIDENCE:")
    print(f"Business explicitly states: 'you have never been a customer at our shop'")
    print(f"This provides definitive proof that the reviewer did not visit/use the service")
    print(f"Combined with negative review = clear 'Rant without visit' violation")
    
    return analysis

def comprehensive_label_validation(df):
    """Validate all predicted label categories for accuracy"""
    
    print("="*80)
    print("COMPREHENSIVE LABEL VALIDATION ANALYSIS")
    print("="*80)
    
    print("\n1. OVERALL LABEL DISTRIBUTION:")
    distribution = df['predicted_label'].value_counts()
    print(distribution)
    
    validation_results = {}
    all_prompting_issues = []
    
    categories = [c for c in df['predicted_label'].unique() if pd.notna(c)]

    for category in categories:
        print(f"\n{'='*60}")
        print(f"ANALYZING: {str(category).upper()}")
        print(f"{'='*60}")
        
        category_data = df[df['predicted_label'] == category]
        total_in_category = len(category_data)
        sample_size = len(category_data)  # Use ALL data
        sample_data = category_data  # No sampling
        
        correct_count = 0
        mislabeled_count = 0
        correct_examples = []
        mislabeled_examples = []
        
        for idx, row in sample_data.iterrows():
            text = str(row['text'])
            business_category = str(row.get('category_str', 'Unknown'))
            rating = row.get('rating', 'N/A')
            has_response = str(row.get('resp', '')).strip() not in ['', 'nan', 'None']
            
            resp_text = row.get('resp', '')
            analysis = analyze_single_review(text, category, business_category, rating, has_response, resp_text)
            
            if analysis['is_correct']:
                correct_count += 1
                correct_examples.append({
                    'text': text,
                    'business_category': business_category,
                    'rating': rating,
                    'has_response': has_response,
                    'reason': analysis['reason']
                })
            else:
                mislabeled_count += 1
                mislabeled_examples.append({
                    'text': text,
                    'business_category': business_category,
                    'rating': rating,
                    'has_response': has_response,
                    'suggested_label': analysis['suggested_label'],
                    'reason': analysis['reason']
                })
        
        accuracy = (correct_count / sample_size) * 100
        
        print(f"Total samples in category: {total_in_category}")
        print(f"CATEGORY SUMMARY:")
        print(f"Total samples in dataset: {total_in_category}")
        print(f"Analyzed sample: {sample_size}")
        print(f"Correct labels: {correct_count}/{sample_size} ({accuracy:.1f}%)")
        print(f"Mislabeled: {mislabeled_count}/{sample_size} ({100-accuracy:.1f}%)")
        
        print(f"\n--- CORRECTLY LABELED EXAMPLES ---")
        for i, example in enumerate(correct_examples[:10], 1):
            print(f"\n{i}. CORRECT EXAMPLE:")
            print(f"   TEXT: {example['text']}")
            print(f"   BUSINESS CATEGORY: {example['business_category']}")
            print(f"   RATING: {example['rating']}")
            print(f"   HAS BUSINESS RESPONSE: {example['has_response']}")
            print(f"   WHY CORRECT: {example['reason']}")
            print("-" * 60)
        
        print(f"\n--- MISLABELED EXAMPLES ---")
        for i, example in enumerate(mislabeled_examples[:10], 1):
            print(f"\n{i}. MISLABELED EXAMPLE:")
            print(f"   TEXT: {example['text']}")
            print(f"   BUSINESS CATEGORY: {example['business_category']}")
            print(f"   RATING: {example['rating']}")
            print(f"   HAS BUSINESS RESPONSE: {example['has_response']}")
            print(f"   CURRENT LABEL: {category}")
            print(f"   SUGGESTED LABEL: {example['suggested_label']}")
            print(f"   WHY MISLABELED: {example['reason']}")
            print("-" * 60)
        
        prompting_issue = analyze_prompting_issues(category, accuracy, correct_examples, mislabeled_examples)
        all_prompting_issues.append(prompting_issue)
        
        validation_results[category] = {
            'accuracy': accuracy,
            'correct_count': correct_count,
            'mislabeled_count': mislabeled_count,
            'total_samples': total_in_category
        }
    
    create_consolidated_prompting_strategy(all_prompting_issues, validation_results)
    
    return validation_results

def analyze_single_review(text, current_label, business_category, rating, has_response, resp_text=""):
    """Enhanced analysis including business response text"""
    
    # Extract response text if available
    business_response = ""
    if has_response and resp_text and str(resp_text) != 'nan':
        try:
            if isinstance(resp_text, str) and resp_text.startswith('{'):
                resp_dict = ast.literal_eval(resp_text)
                business_response = resp_dict.get('text', '')
            elif isinstance(resp_text, dict):
                business_response = resp_text.get('text', '')
            else:
                business_response = str(resp_text)
        except:
            business_response = str(resp_text)
    
    has_ads = has_advertisement_patterns(text)
    has_irrelevant = has_irrelevant_patterns(text, business_category)
    has_rant = has_rant_no_visit_patterns(text, rating, has_response, business_response)
    is_clean = is_actually_clean_review(text, business_category, business_response)
    
    if has_ads:
        suggested = "Advertisement"
        confidence = "High"
        reason = "Contains promotional content or links"
    elif has_irrelevant:
        suggested = "Irrelevant content"
        confidence = "High"
        reason = f"Content not related to business type ({business_category})"
    elif has_rant:
        suggested = "Rant without visit"
        confidence = "High" if "never been a customer" in business_response.lower() else "Medium"
        reason = "Business confirms no customer relationship" if "never been a customer" in business_response.lower() else "Appears to complain without visiting"
    elif is_clean:
        suggested = "Acceptable review"
        confidence = "Medium"
        reason = "Legitimate review about business experience"
    else:
        if len(text.strip()) < 10:
            suggested = "Low quality review"
            confidence = "Low"
            reason = "Very short review with minimal content"
        else:
            suggested = "Acceptable review"
            confidence = "Low"
            reason = "Cannot determine clear policy violation"
    
    return {
        'suggested_label': suggested,
        'confidence': confidence,
        'reason': reason,
        'is_correct': str(suggested or '').lower().replace(' ', '').replace('_', '') == str(current_label or '').lower().replace(' ', '').replace('_', '')
    }


def has_advertisement_patterns(text):
    """Much stricter advertisement detection - only clear promotional content"""
    strict_ad_patterns = [
        r'www\.\w+|http[s]?://\w+',  # Actual URLs
        r'\b(use code|promo code|coupon code)\s+\w+',  # Specific promo codes
        r'\b(call|text|contact)\s+(us\s+)?at\s*\d{3}',  # Contact with phone numbers
        r'\b(visit our|check our|go to our)\s+(website|site)',  # Direct website promotion
        r'\b(get|save)\s+\d+%\s+(off|discount)',  # Specific discount offers
    ]
    return any(re.search(pattern, text.lower()) for pattern in strict_ad_patterns)

def has_irrelevant_patterns(text, business_category):
    """Much stricter irrelevant content detection - must be clearly off-topic"""
    business_type = business_category.lower() if business_category else ""
    text_lower = text.lower()
    
    # Only flag if explicitly discussing unrelated items as the main topic
    clear_irrelevant_patterns = [
        r'\b(not about|unrelated to|off topic)\b',
        r'(wrong place|different location|thought this was)',
        r'(my new phone|bought a laptop|car problems).*but.*place',
    ]
    
    if any(re.search(pattern, text_lower) for pattern in clear_irrelevant_patterns):
        return True
    
    # Food businesses - only flag if clearly about non-food as main topic
    if any(word in business_type for word in ['restaurant', 'food', 'cafe', 'bar']):
        if re.search(r'(this review is about my|talking about my|discussing my)\s+(phone|car|laptop)', text_lower):
            return True
    
    return False

def has_rant_no_visit_patterns(text, rating, has_response, business_response_text=""):
    """Enhanced rant detection using business response confirmation"""
    
    # Check business response for confirmation of no visit
    if business_response_text and business_response_text.strip():
        business_confirms_no_visit = [
            r'never been a customer',
            r'have not done business with you',
            r'you have never visited',
            r'no record of your visit',
            r'never provided service to you',
            r'do not show.*ever done business with you'
        ]
        
        if any(re.search(pattern, business_response_text.lower()) for pattern in business_confirms_no_visit):
            return True
    
    # Original text-based detection
    explicit_no_visit_patterns = [
        r'\b(never been here|haven\'?t visited this place|didn\'?t go to this place)\b',
        r'\b(never went to this|haven\'?t been to this)\b',
        r'\b(heard from others|someone told me|people say)\b.*\b(terrible|awful|bad|horrible)\b',
        r'\b(based on what I heard|from what I\'ve heard)\b',
    ]
    
    text_indicates_no_visit = any(re.search(pattern, text.lower()) for pattern in explicit_no_visit_patterns)
    
    # Additional signals: Very short negative review + low rating + business denial
    is_very_short_negative = len(text.strip()) < 30 and rating is not None and isinstance(rating, (int, float)) and rating <= 2
    business_denies_service = any(re.search(pattern, business_response_text.lower()) for pattern in [r'never been a customer', r'do not show.*ever done business']) if business_response_text else False
    
    return text_indicates_no_visit or (is_very_short_negative and business_denies_service)

def is_actually_clean_review(text, business_category, business_response):
    """Most reviews should be clean unless clear violations exist"""
    return (len(text.strip()) > 5 and
            not has_advertisement_patterns(text) and
            not has_irrelevant_patterns(text, business_category) and
            not has_rant_no_visit_patterns(text, None, None, business_response))

def analyze_prompting_issues(category, accuracy, correct_examples, mislabeled_examples):
    """Analyze prompting issues for later consolidation"""
    
    issues = {
        'category': category,
        'accuracy': accuracy,
        'main_problem': '',
        'specific_fixes': []
    }
    
    if category == "Advertisement" and accuracy < 80:
        issues['main_problem'] = "Confusing customer recommendations with advertisements"
        issues['specific_fixes'] = [
            "Only flag reviews with actual URLs, promo codes, or phone numbers",
            "Don't flag positive customer experiences as ads",
            "Look for business self-promotion, not customer enthusiasm"
        ]
    elif category == "Low quality review" and accuracy < 50:
        issues['main_problem'] = "Flagging legitimate detailed reviews as low quality"
        issues['specific_fixes'] = [
            "Only flag extremely short reviews (under 10 characters)",
            "Don't flag reviews with specific experiences as low quality",
            "Focus on meaningless reviews like single words"
        ]
    elif category == "Irrelevant content" and accuracy < 80:
        issues['main_problem'] = "Flagging relevant content as irrelevant"
        issues['specific_fixes'] = [
            "Food/kitchen/service content IS relevant to restaurants",
            "Only flag if review explicitly discusses unrelated topics",
            "Context matters - enthusiastic food reviews are relevant"
        ]
    elif category == "Rant without visit" and accuracy < 80:
        issues['main_problem'] = "Flagging reviews with clear visit evidence as non-visitor rants"
        issues['specific_fixes'] = [
            "Look for explicit 'never been here' language",
            "Reviews mentioning staff interaction show visits",
            "Detailed service descriptions indicate actual experience",
            "Use business responses that deny customer relationship as strong evidence"
        ]
    
    return issues

def create_consolidated_prompting_strategy(all_issues, validation_results):
    """Create consolidated prompting improvements at the end"""
    
    print(f"\n{'='*80}")
    print("CONSOLIDATED PROMPTING IMPROVEMENT STRATEGY")
    print(f"{'='*80}")
    
    print("\nACCURACY SUMMARY BY CATEGORY:")
    for category, results in validation_results.items():
        print(f"{category:25}: {results['accuracy']:5.1f}% accurate")
    
    print("\nMAJOR ISSUES IDENTIFIED:")
    for issue in all_issues:
        if issue['main_problem']:
            print(f"\n{issue['category']}:")
            print(f"  Problem: {issue['main_problem']}")
            for fix in issue['specific_fixes']:
                print(f"  Fix: {fix}")
    
    print(f"\nCORRECTED PROMPT STRATEGY:")
    print("""
TASK: Classify this review for policy violations using STRICT criteria.

CONTEXT:
Business: [Business Name]
Category: [Business Category] 
Rating: [1-5 stars]
Review: "[Review Text]"
Business Response: "[If available]"

STRICT PREDICTED LABEL  RULES:

1. ADVERTISEMENT - Only if contains:
   - Actual website URLs (www.site.com, http://)
   - Specific promo codes ("use code SAVE20")
   - Phone numbers with "call us at"
   - Direct business promotion language
   NOT customer enthusiasm or recommendations

2. IRRELEVANT CONTENT - Only if review explicitly discusses:
   - Topics completely unrelated to business type
   - Wrong business entirely
   - Personal matters unrelated to the service
   NOT food reviews for restaurants or service reviews for services

3. RANT WITHOUT VISIT - Only if explicitly states OR business confirms:
   - "Never been here but..."
   - "Haven't visited but heard..."
   - "Based on what others told me..."
   - Business responds "never been a customer" or similar
   NOT detailed negative experiences (these show actual visits)

4. ACCEPTABLE REVIEW - Default for legitimate customer experiences:
   - Any review discussing actual business experience
   - Positive, negative, or neutral customer feedback
   - Reviews matching business category appropriately

DEFAULT: When in doubt, classify as ACCEPTABLE REVIEW
Most customer reviews should be acceptable unless clear violations exist.

ANSWER: [Category]
REASONING: [Why this specific predicted label]
""")

# Main execution
if __name__ == "__main__":
    # First analyze the specific example
    print("STEP 1: ANALYZING SPECIFIC EXAMPLE")
    analyze_specific_example()
    
    print("\n\nSTEP 2: FULL DATASET VALIDATION")
    df = pd.read_csv('classified_reviews.csv', on_bad_lines="skip", engine="python")
    validation_results = comprehensive_label_validation(df)
    
    print(f"\nValidation complete. The specific example demonstrates how business responses can confirm 'Rant without visit' violations.")
# Out:
# STEP 1: ANALYZING SPECIFIC EXAMPLE
# ================================================================================
# SPECIFIC EXAMPLE ANALYSIS
# ================================================================================
# GMAP_ID: 0x872b46a9afb11747:0xbab4f9c1c4625e5e
# REVIEWER NAME: jay Jaysam2415
# RATING: 1
# REVIEW TEXT: All I can say is SMH about this place be careful
# BUSINESS CATEGORY: Transmission shop, Auto machine shop, Auto repair shop, Auto tune up service, Brake shop, Car repair and maintenance
# BUSINESS RESPONSE: Jay, we strive to provide excellent service to our customers. We do not show that we have ever done business with you and you have never been a customer at our shop. I do see that you have recently reviewed 3 other transmission shops around the valley. We would appreciate the opportunity to clear up any misunderstandings and ask that you please contact our shop at your convenience.
#
# ------------------------------------------------------------
# ANALYSIS BREAKDOWN:
# ------------------------------------------------------------
# Review Length: 48 characters
# Rating: 1/5 (negative)
# Has Business Response: Yes
#
# Detailed Pattern Analysis:
# - Advertisement patterns: False
# - Irrelevant content patterns: False
# - Rant without visit patterns: True
# - Is clean review: False
#
# FINAL PREDICTED LABEL:
# Suggested Label: Rant without visit
# Confidence: High
# Reasoning: Business confirms no customer relationship
#
# KEY EVIDENCE:
# Business explicitly states: 'you have never been a customer at our shop'
# This provides definitive proof that the reviewer did not visit/use the service
# Combined with negative review = clear 'Rant without visit' violation
#
#
# STEP 2: FULL DATASET VALIDATION
# ================================================================================
# COMPREHENSIVE LABEL VALIDATION ANALYSIS
# ================================================================================
#
# 1. OVERALL LABEL DISTRIBUTION:
# predicted_label
# ACCEPTABLE REVIEW     12908
# LOW QUALITY REVIEW     1604
# IRRELEVANT CONTENT      295
# ADVERTISEMENT            79
# RANT WITHOUT VISIT       45
# ACCEPTABLE REVIEW         6
# ADVERTISING               1
# Name: count, dtype: int64
#
# ============================================================
# ANALYZING: LOW QUALITY REVIEW
# ============================================================
# Total samples in category: 1604
# CATEGORY SUMMARY:
# Total samples in dataset: 1604
# Analyzed sample: 1604
# Correct labels: 22/1604 (1.4%)
# Mislabeled: 1582/1604 (98.6%)
#
# --- CORRECTLY LABELED EXAMPLES ---
#
# 1. CORRECT EXAMPLE:
#    TEXT: Yum
#    BUSINESS CATEGORY: Coffee shop, Bakery, Dessert shop, Donut shop, Ice cream shop
#    RATING: 4
#    HAS BUSINESS RESPONSE: False
#    WHY CORRECT: Very short review with minimal content
# ------------------------------------------------------------
#
# 2. CORRECT EXAMPLE:
#    TEXT: Great
#    BUSINESS CATEGORY: Steak house, American restaurant, Australian restaurant, Bar, Bar & grill, Gluten-free restaurant, Takeout Restaurant, Restaurant
#    RATING: 5
#    HAS BUSINESS RESPONSE: False
#    WHY CORRECT: Very short review with minimal content
# ------------------------------------------------------------
#
# 3. CORRECT EXAMPLE:
#    TEXT: Yum
#    BUSINESS CATEGORY: Fast food restaurant, American restaurant, Chicken restaurant, Fried chicken takeaway, Takeout Restaurant, Southern restaurant (US)
#    RATING: 5
#    HAS BUSINESS RESPONSE: False
#    WHY CORRECT: Very short review with minimal content
# ------------------------------------------------------------
#
# 4. CORRECT EXAMPLE:
#    TEXT: Good
#    BUSINESS CATEGORY: Car wash
#    RATING: 5
#    HAS BUSINESS RESPONSE: False
#    WHY CORRECT: Very short review with minimal content
# ------------------------------------------------------------
#
# 5. CORRECT EXAMPLE:
#    TEXT: Fresh
#    BUSINESS CATEGORY: Fast food restaurant, Hamburger restaurant
#    RATING: 5
#    HAS BUSINESS RESPONSE: False
#    WHY CORRECT: Very short review with minimal content
# ------------------------------------------------------------
#
# 6. CORRECT EXAMPLE:
#    TEXT: It
#    BUSINESS CATEGORY: Department store, Bathroom supply store, Bedding store, Furniture store, Home goods store, Kitchen supply store, Linens store, Outdoor furniture store
#    RATING: 4
#    HAS BUSINESS RESPONSE: False
#    WHY CORRECT: Very short review with minimal content
# ------------------------------------------------------------
#
# 7. CORRECT EXAMPLE:
#    TEXT: Nice
#    BUSINESS CATEGORY: Shopping mall
#    RATING: 3
#    HAS BUSINESS RESPONSE: False
#    WHY CORRECT: Very short review with minimal content
# ------------------------------------------------------------
#
# 8. CORRECT EXAMPLE:
#    TEXT: Clean
#    BUSINESS CATEGORY: Shopping mall
#    RATING: 5
#    HAS BUSINESS RESPONSE: False
#    WHY CORRECT: Very short review with minimal content
# ------------------------------------------------------------
#
# 9. CORRECT EXAMPLE:
#    TEXT: Great
#    BUSINESS CATEGORY: Shopping mall
#    RATING: 5
#    HAS BUSINESS RESPONSE: False
#    WHY CORRECT: Very short review with minimal content
# ------------------------------------------------------------
#
# 10. CORRECT EXAMPLE:
#    TEXT: Blah
#    BUSINESS CATEGORY: Dollar store, Convenience store, Discount store, Drug store, Grocery store
#    RATING: 3
#    HAS BUSINESS RESPONSE: False
#    WHY CORRECT: Very short review with minimal content
# ------------------------------------------------------------
#
# --- MISLABELED EXAMPLES ---
#
# 1. MISLABELED EXAMPLE:
#    TEXT: Champs is a preferred vendor for New Start Realty & Relocation. Fair pricing and accurate estimated ( yea i crossed check the book times) They have serviced our company and personal vehicles for many years now. Hard to find mechanics that service 3 to 5 ton vehicles and RV's with such care- They are not perfect but they stand by their work. Anxious to refer my clients to the RV concierge service in Surprise opening soon. Thanks guys!
#    BUSINESS CATEGORY: Auto repair shop, Auto air conditioning service, Auto radiator repair service, Auto tune up service, Brake shop, Car repair and maintenance, RV repair shop, RV storage facility, Transmission shop, Wheel alignment service
#    RATING: 5
#    HAS BUSINESS RESPONSE: False
#    CURRENT LABEL: LOW QUALITY REVIEW
#    SUGGESTED LABEL: Acceptable review
#    WHY MISLABELED: Legitimate review about business experience
# ------------------------------------------------------------
#
# 2. MISLABELED EXAMPLE:
#    TEXT: Very nice n quite
#    BUSINESS CATEGORY: Park
#    RATING: 5
#    HAS BUSINESS RESPONSE: False
#    CURRENT LABEL: LOW QUALITY REVIEW
#    SUGGESTED LABEL: Acceptable review
#    WHY MISLABELED: Legitimate review about business experience
# ------------------------------------------------------------
#
# 3. MISLABELED EXAMPLE:
#    TEXT: One of my favorite Chinese buffets a lot of food and always good
#    BUSINESS CATEGORY: Buffet restaurant, Cantonese restaurant, Chinese restaurant, Delivery Chinese restaurant, Takeout Restaurant, Steak house
#    RATING: 5
#    HAS BUSINESS RESPONSE: False
#    CURRENT LABEL: LOW QUALITY REVIEW
#    SUGGESTED LABEL: Acceptable review
#    WHY MISLABELED: Legitimate review about business experience
# ------------------------------------------------------------
#
# 4. MISLABELED EXAMPLE:
#    TEXT: The kids love it
#    BUSINESS CATEGORY: Fast food restaurant
#    RATING: 5
#    HAS BUSINESS RESPONSE: False
#    CURRENT LABEL: LOW QUALITY REVIEW
#    SUGGESTED LABEL: Acceptable review
#    WHY MISLABELED: Legitimate review about business experience
# ------------------------------------------------------------
#
# 5. MISLABELED EXAMPLE:
#    TEXT: Always clean, and slightly hidden. Not a lot of people know about Park West, and it is overshadowed by the nearby Westgate. So, it isn't very crowded. Seats are very comfortable, and there are some good restaurants nearby.
#    BUSINESS CATEGORY: Movie theater
#    RATING: 5
#    HAS BUSINESS RESPONSE: False
#    CURRENT LABEL: LOW QUALITY REVIEW
#    SUGGESTED LABEL: Acceptable review
#    WHY MISLABELED: Legitimate review about business experience
# ------------------------------------------------------------
#
# 6. MISLABELED EXAMPLE:
#    TEXT: Do it yourself or have them do it. No mess to clean up when your done
#    BUSINESS CATEGORY: Pet groomer
#    RATING: 5
#    HAS BUSINESS RESPONSE: False
#    CURRENT LABEL: LOW QUALITY REVIEW
#    SUGGESTED LABEL: Acceptable review
#    WHY MISLABELED: Legitimate review about business experience
# ------------------------------------------------------------
#
# 7. MISLABELED EXAMPLE:
#    TEXT: I would highly recommend this place because of the variety of pasty options and their delicious! I can't wait until go back!
#    BUSINESS CATEGORY: Gastropub, Bar, British restaurant, English restaurant, Live music bar, Pub, Vegan restaurant, Vegetarian restaurant
#    RATING: 5
#    HAS BUSINESS RESPONSE: False
#    CURRENT LABEL: LOW QUALITY REVIEW
#    SUGGESTED LABEL: Acceptable review
#    WHY MISLABELED: Legitimate review about business experience
# ------------------------------------------------------------
#
# 8. MISLABELED EXAMPLE:
#    TEXT: Best theater In the valley,.
#    BUSINESS CATEGORY: Movie theater
#    RATING: 5
#    HAS BUSINESS RESPONSE: False
#    CURRENT LABEL: LOW QUALITY REVIEW
#    SUGGESTED LABEL: Acceptable review
#    WHY MISLABELED: Legitimate review about business experience
# ------------------------------------------------------------
#
# 9. MISLABELED EXAMPLE:
#    TEXT: They do a great job here, but the location of the building is terrible. The drive thru line pours out into the street or blocks all of the parked cars from getting out.
#    BUSINESS CATEGORY: Chinese restaurant, Asian restaurant, Restaurant
#    RATING: 4
#    HAS BUSINESS RESPONSE: False
#    CURRENT LABEL: LOW QUALITY REVIEW
#    SUGGESTED LABEL: Acceptable review
#    WHY MISLABELED: Legitimate review about business experience
# ------------------------------------------------------------
#
# 10. MISLABELED EXAMPLE:
#    TEXT: Love this place. Great food, fresh tortillas. I watched them make the tortillas for my food, now that's fresh. Nice restaurant too.
#    BUSINESS CATEGORY: Mexican restaurant, Burrito restaurant, Caterer, Family restaurant, Restaurant, Taco restaurant, Tex-Mex restaurant
#    RATING: 5
#    HAS BUSINESS RESPONSE: False
#    CURRENT LABEL: LOW QUALITY REVIEW
#    SUGGESTED LABEL: Acceptable review
#    WHY MISLABELED: Legitimate review about business experience
# ------------------------------------------------------------
#
# ============================================================
# ANALYZING: ACCEPTABLE REVIEW
# ============================================================
# Total samples in category: 12908
# CATEGORY SUMMARY:
# Total samples in dataset: 12908
# Analyzed sample: 12908
# Correct labels: 12696/12908 (98.4%)
# Mislabeled: 212/12908 (1.6%)
#
# --- CORRECTLY LABELED EXAMPLES ---
#
# 1. CORRECT EXAMPLE:
#    TEXT: Great theater
#    BUSINESS CATEGORY: Movie theater
#    RATING: 5
#    HAS BUSINESS RESPONSE: False
#    WHY CORRECT: Legitimate review about business experience
# ------------------------------------------------------------
#
# 2. CORRECT EXAMPLE:
#    TEXT: Our server was new and couldn't answer any of our questions, but she was very nice. Our food came out pretty sloppy and our pancakes and hashbrowns were raw. There were a lot of workers there and they were all hanging out around a table with a coworker that was off, which I thought was super unprofessional and the manager should have said something. There were plenty of us waiting for our food.
#    BUSINESS CATEGORY: Restaurant, American restaurant, Breakfast restaurant, Family restaurant
#    RATING: 2
#    HAS BUSINESS RESPONSE: False
#    WHY CORRECT: Legitimate review about business experience
# ------------------------------------------------------------
#
# 3. CORRECT EXAMPLE:
#    TEXT: They are caring, understanding and they have a payment plan so theres no excuse your 4 legged family member to get excellent care they deserve!  Check them out!!
#    BUSINESS CATEGORY: Veterinarian, Emergency veterinarian service, Pet groomer, Veterinary pharmacy
#    RATING: 5
#    HAS BUSINESS RESPONSE: False
#    WHY CORRECT: Legitimate review about business experience
# ------------------------------------------------------------
#
# 4. CORRECT EXAMPLE:
#    TEXT: Walmart seems to be on top of things since covid started. They are stocked now and carry more things that you would have to go on line to find. They still sanitize their carts Frys does not
#    BUSINESS CATEGORY: Department store, Clothing store, Craft store, Discount store, Electronics store, Grocery store, Home goods store, Sporting goods store, Supermarket, Toy store
#    RATING: 5
#    HAS BUSINESS RESPONSE: False
#    WHY CORRECT: Legitimate review about business experience
# ------------------------------------------------------------
#
# 5. CORRECT EXAMPLE:
#    TEXT: Unknown to me
#    BUSINESS CATEGORY: Shopping mall
#    RATING: 5
#    HAS BUSINESS RESPONSE: False
#    WHY CORRECT: Legitimate review about business experience
# ------------------------------------------------------------
#
# 6. CORRECT EXAMPLE:
#    TEXT: This store is an absolute must shop....Wrangler products for less than Walmart prices...
#    BUSINESS CATEGORY: Outlet store, Clothing store, Fashion accessories store, Outlet mall
#    RATING: 5
#    HAS BUSINESS RESPONSE: False
#    WHY CORRECT: Legitimate review about business experience
# ------------------------------------------------------------
#
# 7. CORRECT EXAMPLE:
#    TEXT: Cool stuff. Over priced.
#    BUSINESS CATEGORY: Home goods store, Furniture store, Gift wrap store, Home improvement store, Kitchen supply store, Moving supply store, Office supply store, Shelving store
#    RATING: 3
#    HAS BUSINESS RESPONSE: False
#    WHY CORRECT: Legitimate review about business experience
# ------------------------------------------------------------
#
# 8. CORRECT EXAMPLE:
#    TEXT: Providing a Gentle Journey across the rainbow bridge was exactly what they provided for my pet! Professional, mindful, and caring for me, my pet and my home was what I was looking for and they delivered. Thank you for being so compassionate and understanding to my needs.
#    BUSINESS CATEGORY: Veterinarian
#    RATING: 5
#    HAS BUSINESS RESPONSE: False
#    WHY CORRECT: Legitimate review about business experience
# ------------------------------------------------------------
#
# 9. CORRECT EXAMPLE:
#    TEXT: I have only been here once and this will be my last. Do you train your employees in the drive through to say  "here is your drink in a rude tone, slam the door, reopen the door and hand the customer their food withought a "hello, how are you nor a goodby?" I am reporting you guys to the BBB. This is borderline Hostile customer service. If you don't like getting paid minimum wadge, go get yourself an education!!
#    BUSINESS CATEGORY: Fast food restaurant, Breakfast restaurant, Coffee shop, Hamburger restaurant, Restaurant, Sandwich shop
#    RATING: 1
#    HAS BUSINESS RESPONSE: False
#    WHY CORRECT: Legitimate review about business experience
# ------------------------------------------------------------
#
# 10. CORRECT EXAMPLE:
#    TEXT: Great selection here and Ryan is knowledgeable and helpful in finding the right product(s).I purchased a small vape device that provides nicotine, after I've quit smoking cigarettes a fee months ago. For me, this was a positive solution - no more smoke smells.
#    BUSINESS CATEGORY: Tobacco shop
#    RATING: 5
#    HAS BUSINESS RESPONSE: False
#    WHY CORRECT: Legitimate review about business experience
# ------------------------------------------------------------
#
# --- MISLABELED EXAMPLES ---
#
# 1. MISLABELED EXAMPLE:
#    TEXT: nice
#    BUSINESS CATEGORY: Grocery store, Grocery delivery service
#    RATING: 5
#    HAS BUSINESS RESPONSE: False
#    CURRENT LABEL: ACCEPTABLE REVIEW
#    SUGGESTED LABEL: Low quality review
#    WHY MISLABELED: Very short review with minimal content
# ------------------------------------------------------------
#
# 2. MISLABELED EXAMPLE:
#    TEXT: Yummy
#    BUSINESS CATEGORY: Hamburger restaurant
#    RATING: 5
#    HAS BUSINESS RESPONSE: False
#    CURRENT LABEL: ACCEPTABLE REVIEW
#    SUGGESTED LABEL: Low quality review
#    WHY MISLABELED: Very short review with minimal content
# ------------------------------------------------------------
#
# 3. MISLABELED EXAMPLE:
#    TEXT: Yum
#    BUSINESS CATEGORY: Mexican restaurant, Restaurant
#    RATING: 5
#    HAS BUSINESS RESPONSE: False
#    CURRENT LABEL: ACCEPTABLE REVIEW
#    SUGGESTED LABEL: Low quality review
#    WHY MISLABELED: Very short review with minimal content
# ------------------------------------------------------------
#
# 4. MISLABELED EXAMPLE:
#    TEXT: Great
#    BUSINESS CATEGORY: Cannabis store
#    RATING: 5
#    HAS BUSINESS RESPONSE: False
#    CURRENT LABEL: ACCEPTABLE REVIEW
#    SUGGESTED LABEL: Low quality review
#    WHY MISLABELED: Very short review with minimal content
# ------------------------------------------------------------
#
# 5. MISLABELED EXAMPLE:
#    TEXT: Yummm
#    BUSINESS CATEGORY: Coffee shop, Cafe, Juice shop, Tea house
#    RATING: 5
#    HAS BUSINESS RESPONSE: False
#    CURRENT LABEL: ACCEPTABLE REVIEW
#    SUGGESTED LABEL: Low quality review
#    WHY MISLABELED: Very short review with minimal content
# ------------------------------------------------------------
#
# 6. MISLABELED EXAMPLE:
#    TEXT: Tasty
#    BUSINESS CATEGORY: Fast food restaurant, American restaurant, Chicken restaurant, Hamburger restaurant, Sandwich shop
#    RATING: 5
#    HAS BUSINESS RESPONSE: False
#    CURRENT LABEL: ACCEPTABLE REVIEW
#    SUGGESTED LABEL: Low quality review
#    WHY MISLABELED: Very short review with minimal content
# ------------------------------------------------------------
#
# 7. MISLABELED EXAMPLE:
#    TEXT: Yummy
#    BUSINESS CATEGORY: Hamburger restaurant, American restaurant, Diner, Fast food restaurant, Lunch restaurant, Restaurant
#    RATING: 5
#    HAS BUSINESS RESPONSE: False
#    CURRENT LABEL: ACCEPTABLE REVIEW
#    SUGGESTED LABEL: Low quality review
#    WHY MISLABELED: Very short review with minimal content
# ------------------------------------------------------------
#
# 8. MISLABELED EXAMPLE:
#    TEXT: By
#    BUSINESS CATEGORY: Hair salon, Beauty salon
#    RATING: 5
#    HAS BUSINESS RESPONSE: False
#    CURRENT LABEL: ACCEPTABLE REVIEW
#    SUGGESTED LABEL: Low quality review
#    WHY MISLABELED: Very short review with minimal content
# ------------------------------------------------------------
#
# 9. MISLABELED EXAMPLE:
#    TEXT: Galaxy sales' in different location now with new management, items are expensive!!!  Service is friendly and knowledgeable.
#    BUSINESS CATEGORY: Leather goods store, Craft store, Gift shop, Native american goods store, Tack shop
#    RATING: 2
#    HAS BUSINESS RESPONSE: False
#    CURRENT LABEL: ACCEPTABLE REVIEW
#    SUGGESTED LABEL: Irrelevant content
#    WHY MISLABELED: Content not related to business type (Leather goods store, Craft store, Gift shop, Native american goods store, Tack shop)
# ------------------------------------------------------------
#
# 10. MISLABELED EXAMPLE:
#    TEXT: Nice
#    BUSINESS CATEGORY: Shopping mall, Clothing store, Restaurant
#    RATING: 3
#    HAS BUSINESS RESPONSE: False
#    CURRENT LABEL: ACCEPTABLE REVIEW
#    SUGGESTED LABEL: Low quality review
#    WHY MISLABELED: Very short review with minimal content
# ------------------------------------------------------------
#
# ============================================================
# ANALYZING: IRRELEVANT CONTENT
# ============================================================
# Total samples in category: 295
# CATEGORY SUMMARY:
# Total samples in dataset: 295
# Analyzed sample: 295
# Correct labels: 0/295 (0.0%)
# Mislabeled: 295/295 (100.0%)
#
# --- CORRECTLY LABELED EXAMPLES ---
#
# --- MISLABELED EXAMPLES ---
#
# 1. MISLABELED EXAMPLE:
#    TEXT: Nice friendly staff
#    BUSINESS CATEGORY: Resort hotel
#    RATING: 4
#    HAS BUSINESS RESPONSE: False
#    CURRENT LABEL: IRRELEVANT CONTENT
#    SUGGESTED LABEL: Acceptable review
#    WHY MISLABELED: Legitimate review about business experience
# ------------------------------------------------------------
#
# 2. MISLABELED EXAMPLE:
#    TEXT: Food is always good and the service was amazing.
#    BUSINESS CATEGORY: Restaurant, Bar, Brewery, Sports bar
#    RATING: 5
#    HAS BUSINESS RESPONSE: False
#    CURRENT LABEL: IRRELEVANT CONTENT
#    SUGGESTED LABEL: Acceptable review
#    WHY MISLABELED: Legitimate review about business experience
# ------------------------------------------------------------
#
# 3. MISLABELED EXAMPLE:
#    TEXT: Great food
#    BUSINESS CATEGORY: Pizza restaurant, American restaurant, Chicken wings restaurant, Fast food restaurant, Pizza delivery, Pizza Takeout
#    RATING: 5
#    HAS BUSINESS RESPONSE: False
#    CURRENT LABEL: IRRELEVANT CONTENT
#    SUGGESTED LABEL: Acceptable review
#    WHY MISLABELED: Legitimate review about business experience
# ------------------------------------------------------------
#
# 4. MISLABELED EXAMPLE:
#    TEXT: 👍👍
#    BUSINESS CATEGORY: Department store, Clothing store, Furniture store, Jewelry store, Shoe store
#    RATING: 5
#    HAS BUSINESS RESPONSE: False
#    CURRENT LABEL: IRRELEVANT CONTENT
#    SUGGESTED LABEL: Low quality review
#    WHY MISLABELED: Very short review with minimal content
# ------------------------------------------------------------
#
# 5. MISLABELED EXAMPLE:
#    TEXT: Always friendly service and good food value!
#    BUSINESS CATEGORY: Diner, American restaurant, Breakfast restaurant
#    RATING: 4
#    HAS BUSINESS RESPONSE: False
#    CURRENT LABEL: IRRELEVANT CONTENT
#    SUGGESTED LABEL: Acceptable review
#    WHY MISLABELED: Legitimate review about business experience
# ------------------------------------------------------------
#
# 6. MISLABELED EXAMPLE:
#    TEXT: Of course Subway is good food as always. I work at Subway also.
#    BUSINESS CATEGORY: Grocery store, Grocery delivery service
#    RATING: 5
#    HAS BUSINESS RESPONSE: False
#    CURRENT LABEL: IRRELEVANT CONTENT
#    SUGGESTED LABEL: Acceptable review
#    WHY MISLABELED: Legitimate review about business experience
# ------------------------------------------------------------
#
# 7. MISLABELED EXAMPLE:
#    TEXT: Great environment.
#    BUSINESS CATEGORY: Garden center, Landscaping supply store, Plant nursery
#    RATING: 5
#    HAS BUSINESS RESPONSE: False
#    CURRENT LABEL: IRRELEVANT CONTENT
#    SUGGESTED LABEL: Acceptable review
#    WHY MISLABELED: Legitimate review about business experience
# ------------------------------------------------------------
#
# 8. MISLABELED EXAMPLE:
#    TEXT: It was awesome, the service was excellent, the waitress was excellent, and we didnt hve to wait a long time for our food. Maybe 20 minutes and they were busy. It was during lunch hour today.
#    BUSINESS CATEGORY: Tex-Mex restaurant, American restaurant, Bar, Bar & grill, Hamburger restaurant, Mexican restaurant, Restaurant
#    RATING: 5
#    HAS BUSINESS RESPONSE: False
#    CURRENT LABEL: IRRELEVANT CONTENT
#    SUGGESTED LABEL: Acceptable review
#    WHY MISLABELED: Legitimate review about business experience
# ------------------------------------------------------------
#
# 9. MISLABELED EXAMPLE:
#    TEXT: This place is great so great it turned me supa sexy
#    BUSINESS CATEGORY: Restaurant, American restaurant, Dessert restaurant, Takeout Restaurant
#    RATING: 5
#    HAS BUSINESS RESPONSE: False
#    CURRENT LABEL: IRRELEVANT CONTENT
#    SUGGESTED LABEL: Acceptable review
#    WHY MISLABELED: Legitimate review about business experience
# ------------------------------------------------------------
#
# 10. MISLABELED EXAMPLE:
#    TEXT: Great indoor and outdoor activities to keep the whole family busy. Many eating options in NH literally 10 minutes from the museum.
#    BUSINESS CATEGORY: Science museum, Museum, Non-profit organization, Tourist attraction
#    RATING: 5
#    HAS BUSINESS RESPONSE: False
#    CURRENT LABEL: IRRELEVANT CONTENT
#    SUGGESTED LABEL: Acceptable review
#    WHY MISLABELED: Legitimate review about business experience
# ------------------------------------------------------------
#
# ============================================================
# ANALYZING: ADVERTISEMENT
# ============================================================
# Total samples in category: 79
# CATEGORY SUMMARY:
# Total samples in dataset: 79
# Analyzed sample: 79
# Correct labels: 0/79 (0.0%)
# Mislabeled: 79/79 (100.0%)
#
# --- CORRECTLY LABELED EXAMPLES ---
#
# --- MISLABELED EXAMPLES ---
#
# 1. MISLABELED EXAMPLE:
#    TEXT: Clean overall which is what we should expect for a new building however, our hostess was our server (maybe a waitress went home sick) our hostess/server was very busy so it took a while to get our food 25 min by then it was cold.  No refills offered on drinks ( my friend's glass was empty halfway through the meal. Bathrooms where clean but, no toilet paper in the woman's stall and soap came from a home style pump bottle, the wall mounted soap dispensers were empty in both bathrooms. Good food and conversation distracted from the bad. Felt sorry for our hostess/waitress tipped 25%
#    BUSINESS CATEGORY: Restaurant, American restaurant, Breakfast restaurant, Family restaurant
#    RATING: 3
#    HAS BUSINESS RESPONSE: False
#    CURRENT LABEL: ADVERTISEMENT
#    SUGGESTED LABEL: Acceptable review
#    WHY MISLABELED: Legitimate review about business experience
# ------------------------------------------------------------
#
# 2. MISLABELED EXAMPLE:
#    TEXT: Outside band and dancing
#    BUSINESS CATEGORY: American restaurant, Chicken wings restaurant
#    RATING: 4
#    HAS BUSINESS RESPONSE: False
#    CURRENT LABEL: ADVERTISEMENT
#    SUGGESTED LABEL: Acceptable review
#    WHY MISLABELED: Legitimate review about business experience
# ------------------------------------------------------------
#
# 3. MISLABELED EXAMPLE:
#    TEXT: Good park to go to if you have a family and want to hang out for a reunion or birthday party
#    BUSINESS CATEGORY: Park
#    RATING: 5
#    HAS BUSINESS RESPONSE: False
#    CURRENT LABEL: ADVERTISEMENT
#    SUGGESTED LABEL: Acceptable review
#    WHY MISLABELED: Legitimate review about business experience
# ------------------------------------------------------------
#
# 4. MISLABELED EXAMPLE:
#    TEXT: Store remodel is great, there was a ok supply of meats the only concern was I had to leave area instantly to use inhaler, due to the bleach, or chemical they used near the meat section. It was a bit much and as a fellow asthmatic it's truly unsafe.
#    BUSINESS CATEGORY: Grocery store
#    RATING: 3
#    HAS BUSINESS RESPONSE: False
#    CURRENT LABEL: ADVERTISEMENT
#    SUGGESTED LABEL: Acceptable review
#    WHY MISLABELED: Legitimate review about business experience
# ------------------------------------------------------------
#
# 5. MISLABELED EXAMPLE:
#    TEXT: This place appears to be out of business :/ when I came here before it was really good though
#    BUSINESS CATEGORY: Used bicycle shop, Bicycle repair shop, Bicycle Shop, Consignment shop
#    RATING: 5
#    HAS BUSINESS RESPONSE: False
#    CURRENT LABEL: ADVERTISEMENT
#    SUGGESTED LABEL: Acceptable review
#    WHY MISLABELED: Legitimate review about business experience
# ------------------------------------------------------------
#
# 6. MISLABELED EXAMPLE:
#    TEXT: Magical! Great food!
#    BUSINESS CATEGORY: Pizza restaurant, Gift shop
#    RATING: 5
#    HAS BUSINESS RESPONSE: False
#    CURRENT LABEL: ADVERTISEMENT
#    SUGGESTED LABEL: Acceptable review
#    WHY MISLABELED: Legitimate review about business experience
# ------------------------------------------------------------
#
# 7. MISLABELED EXAMPLE:
#    TEXT: Love their coffee!!Fast service!
#    BUSINESS CATEGORY: Coffee shop, Bagel shop, Bakery, Breakfast restaurant, Donut shop, Fast food restaurant, Takeout Restaurant
#    RATING: 5
#    HAS BUSINESS RESPONSE: False
#    CURRENT LABEL: ADVERTISEMENT
#    SUGGESTED LABEL: Acceptable review
#    WHY MISLABELED: Legitimate review about business experience
# ------------------------------------------------------------
#
# 8. MISLABELED EXAMPLE:
#    TEXT: Very pricey
#    BUSINESS CATEGORY: Bar, Restaurant, Sports bar
#    RATING: 5
#    HAS BUSINESS RESPONSE: False
#    CURRENT LABEL: ADVERTISEMENT
#    SUGGESTED LABEL: Acceptable review
#    WHY MISLABELED: Legitimate review about business experience
# ------------------------------------------------------------
#
# 9. MISLABELED EXAMPLE:
#    TEXT: Love all the deals
#    BUSINESS CATEGORY: Variety store, Candy store, Fashion accessories store, Gift shop, Toy store
#    RATING: 5
#    HAS BUSINESS RESPONSE: False
#    CURRENT LABEL: ADVERTISEMENT
#    SUGGESTED LABEL: Acceptable review
#    WHY MISLABELED: Legitimate review about business experience
# ------------------------------------------------------------
#
# 10. MISLABELED EXAMPLE:
#    TEXT: Great place to stop on our way to Vegas. Always clean.
#    BUSINESS CATEGORY: Gas station, Rest stop, Truck stop
#    RATING: 5
#    HAS BUSINESS RESPONSE: False
#    CURRENT LABEL: ADVERTISEMENT
#    SUGGESTED LABEL: Acceptable review
#    WHY MISLABELED: Legitimate review about business experience
# ------------------------------------------------------------
#
# ============================================================
# ANALYZING: ADVERTISING
# ============================================================
# Total samples in category: 1
# CATEGORY SUMMARY:
# Total samples in dataset: 1
# Analyzed sample: 1
# Correct labels: 0/1 (0.0%)
# Mislabeled: 1/1 (100.0%)
#
# --- CORRECTLY LABELED EXAMPLES ---
#
# --- MISLABELED EXAMPLES ---
#
# 1. MISLABELED EXAMPLE:
#    TEXT: Good stuff. Hurry with your pistachio!
#    BUSINESS CATEGORY: Restaurant
#    RATING: 5
#    HAS BUSINESS RESPONSE: False
#    CURRENT LABEL: ADVERTISING
#    SUGGESTED LABEL: Acceptable review
#    WHY MISLABELED: Legitimate review about business experience
# ------------------------------------------------------------
#
# ============================================================
# ANALYZING: RANT WITHOUT VISIT
# ============================================================
# Total samples in category: 45
# CATEGORY SUMMARY:
# Total samples in dataset: 45
# Analyzed sample: 45
# Correct labels: 0/45 (0.0%)
# Mislabeled: 45/45 (100.0%)
#
# --- CORRECTLY LABELED EXAMPLES ---
#
# --- MISLABELED EXAMPLES ---
#
# 1. MISLABELED EXAMPLE:
#    TEXT: Long lines .cashiers are so slow.an talk an take there time. Other day i went to deil asked for a certain amount of salad. The guy over filled it .i said not ok .he dumped some in trash .hows that .?still to much .I said thats not what i wanted .plus after slicing meat he kept his slimy gloves on an handled my containers .Then told him .Your supposed to change your gloves .before so now i dont want anything. Comlained to manager .
#    BUSINESS CATEGORY: Grocery store, Grocery delivery service
#    RATING: 2
#    HAS BUSINESS RESPONSE: False
#    CURRENT LABEL: RANT WITHOUT VISIT
#    SUGGESTED LABEL: Acceptable review
#    WHY MISLABELED: Legitimate review about business experience
# ------------------------------------------------------------
#
# 2. MISLABELED EXAMPLE:
#    TEXT: Quick service even without an appointment. Got me out in an hour. Clean and plenty of seating.
#    BUSINESS CATEGORY: Subaru dealer, Auto broker, Auto repair shop, Car dealer
#    RATING: 4
#    HAS BUSINESS RESPONSE: False
#    CURRENT LABEL: RANT WITHOUT VISIT
#    SUGGESTED LABEL: Acceptable review
#    WHY MISLABELED: Legitimate review about business experience
# ------------------------------------------------------------
#
# 3. MISLABELED EXAMPLE:
#    TEXT: Service and food gone down the tubes. I loved this place, so disappointed!
#    BUSINESS CATEGORY: Restaurant, American restaurant, Bakery, Diner, Family restaurant, Traditional American restaurant
#    RATING: 3
#    HAS BUSINESS RESPONSE: False
#    CURRENT LABEL: RANT WITHOUT VISIT
#    SUGGESTED LABEL: Acceptable review
#    WHY MISLABELED: Legitimate review about business experience
# ------------------------------------------------------------
#
# 4. MISLABELED EXAMPLE:
#    TEXT: It was okay but I probably won't go back
#    BUSINESS CATEGORY: Hamburger restaurant, American restaurant, Diner, Fast food restaurant, Lunch restaurant, Restaurant
#    RATING: 3
#    HAS BUSINESS RESPONSE: False
#    CURRENT LABEL: RANT WITHOUT VISIT
#    SUGGESTED LABEL: Acceptable review
#    WHY MISLABELED: Legitimate review about business experience
# ------------------------------------------------------------
#
# 5. MISLABELED EXAMPLE:
#    TEXT: EXCEPT CASHIERS WERE MISSING IN ACTION😂
#    BUSINESS CATEGORY: Dollar store, Convenience store, Discount store, Drug store, Grocery store
#    RATING: 5
#    HAS BUSINESS RESPONSE: False
#    CURRENT LABEL: RANT WITHOUT VISIT
#    SUGGESTED LABEL: Acceptable review
#    WHY MISLABELED: Legitimate review about business experience
# ------------------------------------------------------------
#
# 6. MISLABELED EXAMPLE:
#    TEXT: The honey biscuits are awesome
#    BUSINESS CATEGORY: Chicken restaurant, Family restaurant, Fast food restaurant
#    RATING: 4
#    HAS BUSINESS RESPONSE: False
#    CURRENT LABEL: RANT WITHOUT VISIT
#    SUGGESTED LABEL: Acceptable review
#    WHY MISLABELED: Legitimate review about business experience
# ------------------------------------------------------------
#
# 7. MISLABELED EXAMPLE:
#    TEXT: I always find some different things for groceries at Trader Joe's.  The store is always busy when I go in but still well stocked.  The prices are reasonable.
#    BUSINESS CATEGORY: Grocery store, Cheese shop, Florist, Health food store, Natural goods store, Produce market, Supermarket, Wine store
#    RATING: 4
#    HAS BUSINESS RESPONSE: False
#    CURRENT LABEL: RANT WITHOUT VISIT
#    SUGGESTED LABEL: Acceptable review
#    WHY MISLABELED: Legitimate review about business experience
# ------------------------------------------------------------
#
# 8. MISLABELED EXAMPLE:
#    TEXT: The hotel is dated, plus in need of a renovation.
#    BUSINESS CATEGORY: Hotel, Lodge
#    RATING: 2
#    HAS BUSINESS RESPONSE: False
#    CURRENT LABEL: RANT WITHOUT VISIT
#    SUGGESTED LABEL: Acceptable review
#    WHY MISLABELED: Legitimate review about business experience
# ------------------------------------------------------------
#
# 9. MISLABELED EXAMPLE:
#    TEXT: Love the gyros
#    BUSINESS CATEGORY: Greek restaurant, Bar, Cafe, European restaurant, Italian restaurant, Mediterranean restaurant
#    RATING: 5
#    HAS BUSINESS RESPONSE: False
#    CURRENT LABEL: RANT WITHOUT VISIT
#    SUGGESTED LABEL: Acceptable review
#    WHY MISLABELED: Legitimate review about business experience
# ------------------------------------------------------------
#
# 10. MISLABELED EXAMPLE:
#    TEXT: micro-brew beer. Pizza is pretty good though a little pricey. I usually go for the wings (they always have awesome sauces), calzone, or their amazing hop bread. Only downside to this bar is that it's impossible to get a seat on a busy night or any weekend. A hostess would be nice so if you had to wait, you wouldn't have to hover over another person's table or get pushed by that other guy who's also waiting. Edit: they have a hostess now! Yay!
#    BUSINESS CATEGORY: Pizza restaurant, Bar
#    RATING: 5
#    HAS BUSINESS RESPONSE: False
#    CURRENT LABEL: RANT WITHOUT VISIT
#    SUGGESTED LABEL: Acceptable review
#    WHY MISLABELED: Legitimate review about business experience
# ------------------------------------------------------------
#
# ============================================================
# ANALYZING: ACCEPTABLE REVIEW
# ============================================================
# Total samples in category: 6
# CATEGORY SUMMARY:
# Total samples in dataset: 6
# Analyzed sample: 6
# Correct labels: 6/6 (100.0%)
# Mislabeled: 0/6 (0.0%)
#
# --- CORRECTLY LABELED EXAMPLES ---
#
# 1. CORRECT EXAMPLE:
#    TEXT: Beauty + Tranquility = Reboot I felt so revitalized after visiting the Friendship Garden for the Full Moon Event!!
#    BUSINESS CATEGORY: Botanical garden, Tourist attraction
#    RATING: 5
#    HAS BUSINESS RESPONSE: False
#    WHY CORRECT: Legitimate review about business experience
# ------------------------------------------------------------
#
# 2. CORRECT EXAMPLE:
#    TEXT: (Translated by Google) When you are in a hurry and you only park where the carts go ???? (Original) Cuando andas muy apurado y solo te estacionas en dónde van las carretas ????
#    BUSINESS CATEGORY: Department store, Clothing store, Craft store, Discount store, Electronics store, Grocery store, Home goods store, Sporting goods store, Supermarket, Toy store
#    RATING: 5
#    HAS BUSINESS RESPONSE: False
#    WHY CORRECT: Legitimate review about business experience
# ------------------------------------------------------------
#
# 3. CORRECT EXAMPLE:
#    TEXT: (Translated by Google) Excellent! (Original) Excelente!
#    BUSINESS CATEGORY: Observatory, Professional services
#    RATING: 5
#    HAS BUSINESS RESPONSE: False
#    WHY CORRECT: Legitimate review about business experience
# ------------------------------------------------------------
#
# 4. CORRECT EXAMPLE:
#    TEXT: Best sandwiches in town. Food: 5/5 Service: 5/5 Ambiance: 3/5
#    BUSINESS CATEGORY: Sandwich shop
#    RATING: 5
#    HAS BUSINESS RESPONSE: False
#    WHY CORRECT: Legitimate review about business experience
# ------------------------------------------------------------
#
# 5. CORRECT EXAMPLE:
#    TEXT: (Translated by Google) Deliitastic (Original)Deliitastic
#    BUSINESS CATEGORY: Ice cream shop
#    RATING: 5
#    HAS BUSINESS RESPONSE: False
#    WHY CORRECT: Legitimate review about business experience
# ------------------------------------------------------------
#
# 6. CORRECT EXAMPLE:
#    TEXT: Theatre was neat and clean and the seats were comfortable. Restroom clean.. Enjoyed the movie .
#    BUSINESS CATEGORY: Movie theater
#    RATING: 4
#    HAS BUSINESS RESPONSE: False
#    WHY CORRECT: Legitimate review about business experience
# ------------------------------------------------------------
#
# --- MISLABELED EXAMPLES ---
#
# ================================================================================
# CONSOLIDATED PROMPTING IMPROVEMENT STRATEGY
# ================================================================================
#
# ACCURACY SUMMARY BY CATEGORY:
# LOW QUALITY REVIEW       :   1.4% accurate
# ACCEPTABLE REVIEW        :  98.4% accurate
# IRRELEVANT CONTENT       :   0.0% accurate
# ADVERTISEMENT            :   0.0% accurate
# ADVERTISING              :   0.0% accurate
# RANT WITHOUT VISIT       :   0.0% accurate
# ACCEPTABLE REVIEW        : 100.0% accurate
#
# MAJOR ISSUES IDENTIFIED:
#
# CORRECTED PROMPT STRATEGY:
#
# TASK: Classify this review for policy violations using STRICT criteria.
#
# CONTEXT:
# Business: [Business Name]
# Category: [Business Category]
# Rating: [1-5 stars]
# Review: "[Review Text]"
# Business Response: "[If available]"
#
# STRICT PREDICTED LABEL  RULES:
#
# 1. ADVERTISEMENT - Only if contains:
#    - Actual website URLs (www.site.com, http://)
#    - Specific promo codes ("use code SAVE20")
#    - Phone numbers with "call us at"
#    - Direct business promotion language
#    NOT customer enthusiasm or recommendations
#
# 2. IRRELEVANT CONTENT - Only if review explicitly discusses:
#    - Topics completely unrelated to business type
#    - Wrong business entirely
#    - Personal matters unrelated to the service
#    NOT food reviews for restaurants or service reviews for services
#
# 3. RANT WITHOUT VISIT - Only if explicitly states OR business confirms:
#    - "Never been here but..."
#    - "Haven't visited but heard..."
#    - "Based on what others told me..."
#    - Business responds "never been a customer" or similar
#    NOT detailed negative experiences (these show actual visits)
#
# 4. ACCEPTABLE REVIEW - Default for legitimate customer experiences:
#    - Any review discussing actual business experience
#    - Positive, negative, or neutral customer feedback
#    - Reviews matching business category appropriately
#
# DEFAULT: When in doubt, classify as ACCEPTABLE REVIEW
# Most customer reviews should be acceptable unless clear violations exist.
#
# ANSWER: [Category]
# REASONING: [Why this specific predicted label]
#
#
# Validation complete. The specific example demonstrates how business responses can confirm 'Rant without visit' violations.

# %% [markdown]
# # Grouped by Suggested Labels

# %%
def print_mismatched_examples(df):
    """Print up to 10 mismatched reviews grouped by suggested label."""
    mismatches = []

    for _, row in df.iterrows():
        text = str(row.get('text') or '')
        business_category = str(row.get('category_str') or 'Unknown')
        rating = row.get('rating', 'N/A')
        has_response = str(row.get('resp') or '').strip() not in ['', 'nan', 'None']
        resp_text = row.get('resp', '')

        # Ensure analysis is never None
        analysis = analyze_single_review(
            text,
            row.get('predicted_label', ''),
            business_category,
            rating,
            has_response,
            resp_text
        )

        if analysis is None:
            continue  # skip if analysis failed

        # Safely coerce both labels to lowercase strings
        current_label = str(row.get('predicted_label') or '').strip().lower()
        suggested_label = str(analysis.get('suggested_label') or '').strip().lower()

        # Skip if either label is empty
        if not suggested_label or not current_label:
            continue

        if suggested_label != current_label:
            mismatches.append({
                'text': text,
                'business_category': business_category,
                'rating': rating,
                'current_label': current_label,
                'suggested_label': suggested_label,
                'reason': analysis.get('reason', '')
            })

    # If nothing found
    if not mismatches:
        print("✅ No mismatches found.")
        return pd.DataFrame()

    mismatches_df = pd.DataFrame(mismatches)

    # Print grouped examples
    for label, group in mismatches_df.groupby("suggested_label"):
        print("=" * 80)
        print(f"SUGGESTED LABEL: {label.upper()}  (showing up to 10 mismatches)")
        print("=" * 80)
        for i, row in group.head(10).iterrows():
            print(f"\n{i+1}. TEXT: {row['text']}")
            print(f"   BUSINESS CATEGORY: {row['business_category']}")
            print(f"   RATING: {row['rating']}")
            print(f"   CURRENT LABEL: {row['current_label']}")
            print(f"   SUGGESTED LABEL: {row['suggested_label']}")
            print(f"   REASON: {row['reason']}")
            print("-" * 60)

    return mismatches_df

mismatches_df = print_mismatched_examples(df)

if not mismatches_df.empty:
    mismatches_df.to_csv("mismatched_examples.csv", index=False)
# Out:
# ================================================================================
# SUGGESTED LABEL: ACCEPTABLE REVIEW  (showing up to 10 mismatches)
# ================================================================================
#
# 1. TEXT: Champs is a preferred vendor for New Start Realty & Relocation. Fair pricing and accurate estimated ( yea i crossed check the book times) They have serviced our company and personal vehicles for many years now. Hard to find mechanics that service 3 to 5 ton vehicles and RV's with such care- They are not perfect but they stand by their work. Anxious to refer my clients to the RV concierge service in Surprise opening soon. Thanks guys!
#    BUSINESS CATEGORY: Auto repair shop, Auto air conditioning service, Auto radiator repair service, Auto tune up service, Brake shop, Car repair and maintenance, RV repair shop, RV storage facility, Transmission shop, Wheel alignment service
#    RATING: 5
#    CURRENT LABEL: low quality review
#    SUGGESTED LABEL: acceptable review
#    REASON: Legitimate review about business experience
# ------------------------------------------------------------
#
# 2. TEXT: Very nice n quite
#    BUSINESS CATEGORY: Park
#    RATING: 5
#    CURRENT LABEL: low quality review
#    SUGGESTED LABEL: acceptable review
#    REASON: Legitimate review about business experience
# ------------------------------------------------------------
#
# 3. TEXT: One of my favorite Chinese buffets a lot of food and always good
#    BUSINESS CATEGORY: Buffet restaurant, Cantonese restaurant, Chinese restaurant, Delivery Chinese restaurant, Takeout Restaurant, Steak house
#    RATING: 5
#    CURRENT LABEL: low quality review
#    SUGGESTED LABEL: acceptable review
#    REASON: Legitimate review about business experience
# ------------------------------------------------------------
#
# 4. TEXT: The kids love it
#    BUSINESS CATEGORY: Fast food restaurant
#    RATING: 5
#    CURRENT LABEL: low quality review
#    SUGGESTED LABEL: acceptable review
#    REASON: Legitimate review about business experience
# ------------------------------------------------------------
#
# 5. TEXT: Always clean, and slightly hidden. Not a lot of people know about Park West, and it is overshadowed by the nearby Westgate. So, it isn't very crowded. Seats are very comfortable, and there are some good restaurants nearby.
#    BUSINESS CATEGORY: Movie theater
#    RATING: 5
#    CURRENT LABEL: low quality review
#    SUGGESTED LABEL: acceptable review
#    REASON: Legitimate review about business experience
# ------------------------------------------------------------
#
# 6. TEXT: Do it yourself or have them do it. No mess to clean up when your done
#    BUSINESS CATEGORY: Pet groomer
#    RATING: 5
#    CURRENT LABEL: low quality review
#    SUGGESTED LABEL: acceptable review
#    REASON: Legitimate review about business experience
# ------------------------------------------------------------
#
# 7. TEXT: I would highly recommend this place because of the variety of pasty options and their delicious! I can't wait until go back!
#    BUSINESS CATEGORY: Gastropub, Bar, British restaurant, English restaurant, Live music bar, Pub, Vegan restaurant, Vegetarian restaurant
#    RATING: 5
#    CURRENT LABEL: low quality review
#    SUGGESTED LABEL: acceptable review
#    REASON: Legitimate review about business experience
# ------------------------------------------------------------
#
# 8. TEXT: Best theater In the valley,.
#    BUSINESS CATEGORY: Movie theater
#    RATING: 5
#    CURRENT LABEL: low quality review
#    SUGGESTED LABEL: acceptable review
#    REASON: Legitimate review about business experience
# ------------------------------------------------------------
#
# 9. TEXT: They do a great job here, but the location of the building is terrible. The drive thru line pours out into the street or blocks all of the parked cars from getting out.
#    BUSINESS CATEGORY: Chinese restaurant, Asian restaurant, Restaurant
#    RATING: 4
#    CURRENT LABEL: low quality review
#    SUGGESTED LABEL: acceptable review
#    REASON: Legitimate review about business experience
# ------------------------------------------------------------
#
# 11. TEXT: Love this place. Great food, fresh tortillas. I watched them make the tortillas for my food, now that's fresh. Nice restaurant too.
#    BUSINESS CATEGORY: Mexican restaurant, Burrito restaurant, Caterer, Family restaurant, Restaurant, Taco restaurant, Tex-Mex restaurant
#    RATING: 5
#    CURRENT LABEL: low quality review
#    SUGGESTED LABEL: acceptable review
#    REASON: Legitimate review about business experience
# ------------------------------------------------------------
# ================================================================================
# SUGGESTED LABEL: ADVERTISEMENT  (showing up to 10 mismatches)
# ================================================================================
#
# 1735. TEXT: Ordered online for take out and the order was said to be ready by 7pm.  Arrived promptly at seven pm and got to the car and the food was cold . Cold fries . Cold sandwiches. Cold pizza . The promo code online doesn't reflect the promo stated.  Disappointing for a $13 sandwich.  Won't return and wouldn't recommend you do either , at least for take out .
#    BUSINESS CATEGORY: Pizza restaurant, Italian restaurant
#    RATING: 2
#    CURRENT LABEL: acceptable review
#    SUGGESTED LABEL: advertisement
#    REASON: Contains promotional content or links
# ------------------------------------------------------------
#
# 3763. TEXT: This place was cool. The storefront was well managed and friendly. The selection was good, and my budtender was very helpful and 1st time customers get 20% off their 1st order, and I got a free 1/8th for spending 100 bucks. Value. You should go here when you're in Phoenix. I will be coming back here often. Check their weekly specials and go on the days you wanna save on your preferred form... 😉 great job guys!
#    BUSINESS CATEGORY: Cannabis store
#    RATING: 4
#    CURRENT LABEL: nan
#    SUGGESTED LABEL: advertisement
#    REASON: Contains promotional content or links
# ------------------------------------------------------------
#
# 5543. TEXT: Guests visiting IHOP who order ahead online or download the IHOP app, can save 20% off your first order with code IHOP20 at checkout. Join IHOP Tuesday, February 25th and get a free short stack of buttermilk pancakes, a chance to win Pancakes for Life and to support a local charity. Thanks IHOP Central and Encanto for the clean dining room and very friendly staff.
#    BUSINESS CATEGORY: Restaurant, American restaurant, Breakfast restaurant, Family restaurant
#    RATING: 5
#    CURRENT LABEL: acceptable review
#    SUGGESTED LABEL: advertisement
#    REASON: Contains promotional content or links
# ------------------------------------------------------------
# ================================================================================
# SUGGESTED LABEL: IRRELEVANT CONTENT  (showing up to 10 mismatches)
# ================================================================================
#
# 100. TEXT: Galaxy sales' in different location now with new management, items are expensive!!!  Service is friendly and knowledgeable.
#    BUSINESS CATEGORY: Leather goods store, Craft store, Gift shop, Native american goods store, Tack shop
#    RATING: 2
#    CURRENT LABEL: acceptable review
#    SUGGESTED LABEL: irrelevant content
#    REASON: Content not related to business type (Leather goods store, Craft store, Gift shop, Native american goods store, Tack shop)
# ------------------------------------------------------------
#
# 114. TEXT: They cancelled my toddler's swim class last minute and didnt call me early enough to give me any time to sign up for swim at a different location. They refused to slot me into any other classes even though they had already guaranteed me a spot, and their next opening isn't for over a month. To top it all off they won't refund me online even though I paid online. They're making me come in and sign "paperwork" before they'll give my $60 back. Never going here again, id rather drive 20 min out of my way for a cheaper class so I dont have to deal with them.
#    BUSINESS CATEGORY: Gym, Basketball court, Church, Event venue, Fitness center, Playground, Recreation center, Rock climbing, Soccer field, Swimming pool
#    RATING: 1
#    CURRENT LABEL: acceptable review
#    SUGGESTED LABEL: irrelevant content
#    REASON: Content not related to business type (Gym, Basketball court, Church, Event venue, Fitness center, Playground, Recreation center, Rock climbing, Soccer field, Swimming pool)
# ------------------------------------------------------------
#
# 474. TEXT: I love Cafe Rio, but this location was a disappointment, unfortunately. The staff was slow with orders and the first guy on the order line was in a really sour mood. We were in line for over 20 minutes. At least the food is always delicious, so I will go to a different location from now on.
#    BUSINESS CATEGORY: Mexican restaurant, Burrito restaurant, Caterer, Family restaurant, Restaurant, Taco restaurant, Tex-Mex restaurant
#    RATING: 2
#    CURRENT LABEL: acceptable review
#    SUGGESTED LABEL: irrelevant content
#    REASON: Content not related to business type (Mexican restaurant, Burrito restaurant, Caterer, Family restaurant, Restaurant, Taco restaurant, Tex-Mex restaurant)
# ------------------------------------------------------------
#
# 545. TEXT: INITIALLY I WAS FASCINATED WITH DEFALCO'S, AND GAVE THEM A FIVE-STAR REVIEW. NOW, AFTER THREE TERRIBLE EXPERIENCES (IN A ROW), IT'S HIGHLY UNLIKELY THAT I'LL EVER RETURN. EACH OF THESE INSTANCES HAS COST THEM ONE STAR. 1) CALLED TO ASK IF THEY HAD IMPORTED CANS OF FAVA BEANS, THE REPLY WAS "YES", BUT WHEN I GET TO DEFALCO'S NO FAVA BEANS....... THOUGHT THIS WAS AN ITALIAN GROCER!? 2) ORDERED A "HOT" SANDWICH, AND BY THE TIME I RECEIVED IT, IT WAS BARELY WARM....... LIKE 30 OUT OF THE 40 MINUTES I WAITED FOR IT, IT JUST SAT SOMEPLACE GETTING COLD. 3) THE LAST STRAW WAS ONE OF THE RUDEST PEOPLE I'VE EVER MET CUSSING ME OUT WHEN I TOLD HER THE ORDER IN THE BAG SHE HANDED ME WAS NOT MY ORDER AT ALL! STAYING OPEN DURING THESE TIMES IS HARD ENOUGH........... YOU DON'T NEED SOMEONE WITH A NASTY ATTITUDE, AND EVEN NASTIER MOUTH COSTING YOU LOYAL PATRONS!! REMEDY THE SITUATION!!
#    BUSINESS CATEGORY: Italian restaurant, Deli, Restaurant, Wine store
#    RATING: 2
#    CURRENT LABEL: acceptable review
#    SUGGESTED LABEL: irrelevant content
#    REASON: Content not related to business type (Italian restaurant, Deli, Restaurant, Wine store)
# ------------------------------------------------------------
#
# 569. TEXT: The food is always fine but the service is TERRIBLE!!! We go to this one because it’s literally just down the road but we are going to start going out of our way to go to a different location. This one is NOTORIOUS in my family for getting things wrong. Every single time we go they forget something or they change sides without telling us or just flat out get the order wrong. I’m quite done with it.
#    BUSINESS CATEGORY: Fast food restaurant, Hamburger restaurant, Restaurant
#    RATING: 2
#    CURRENT LABEL: acceptable review
#    SUGGESTED LABEL: irrelevant content
#    REASON: Content not related to business type (Fast food restaurant, Hamburger restaurant, Restaurant)
# ------------------------------------------------------------
#
# 997. TEXT: I have been meaning to get over to Gallo Blanco for sometime now but always end up going to their sister restaurant Otro Cafe. So glad we decided to do dinner here last night! Immediately upon entering Gallo I was really impressed with the space and the vibe. The space itself is just gorgeous, it's much bigger than I imagined it to be. When I initially saw some reviews with pictures posted of the interior and the large food menu posted over a counter I thought this was a restaurant that you ordered at the counter and then took your food and sat down. I wasn't sure if that was an experience I was looking to have. It is in fact a full service restaurant. I was guilty of judging a book by it's cover! We were greeted by a server who let us know that they were on a 30 minute wait (7:15 ish on a Friday night, which seems about right) but that the bar was open seating and we were welcome to eat in there, grab a drink, or just wait for a table. We decided to wait for a table and we were pleasantly surprised to be sat within about 5 minutes of being there. SCORE!!! We ordered the Chip and Guac salsa sampler to start with which was awesome. I loved the different salsas that complimented the guac and the chips are always on point! For our main entrees we ordered the chicken enchiladas a couple of carne asada tacos. Everything is so flavorful. I am a huge fan of Otro Cafe especially the flour tortillas which are out of this world AMAZING so I was a little bummed that my tacos weren't wrapped in those heavenly numbers. The only con's I have to share would be the noise level. With the beautiful construction of the space the noise carries so if you're trying to have a quiet intimate dinner this may not be the place to do that. There is also patio seating which I imagine would be a better option to dine if you're looking for less noise. Parking I can imagine could also be an issue especially as we get into these gorgeous nights that we are so famous for in AZ. Overall I loved Gallo Blanco's and can't wait to come back and try out some other items on their menu!
#    BUSINESS CATEGORY: Mexican restaurant, Bar, Latin American restaurant
#    RATING: 5
#    CURRENT LABEL: nan
#    SUGGESTED LABEL: irrelevant content
#    REASON: Content not related to business type (Mexican restaurant, Bar, Latin American restaurant)
# ------------------------------------------------------------
#
# 1764. TEXT: Terrible, 3 1/2 hrs my friend waited for his cab, & then took him to the wrong place, he's handicap, w/ 1 leg & the cab driver took him way north, & just dropped him off, even aFter I told him where to take him which was rite down the street at mavericks bad! Never use them again!!
#    BUSINESS CATEGORY: Taxi service
#    RATING: 1
#    CURRENT LABEL: acceptable review
#    SUGGESTED LABEL: irrelevant content
#    REASON: Content not related to business type (Taxi service)
# ------------------------------------------------------------
#
# 1804. TEXT: I have been going there for over 14 years in I was a salon owner at a different location but still went there to get my nails done love this place in all the people that work there
#    BUSINESS CATEGORY: Nail salon, Facial spa, Skin care clinic, Waxing hair removal service
#    RATING: 5
#    CURRENT LABEL: acceptable review
#    SUGGESTED LABEL: irrelevant content
#    REASON: Content not related to business type (Nail salon, Facial spa, Skin care clinic, Waxing hair removal service)
# ------------------------------------------------------------
#
# 5196. TEXT: Drove up to a different location and heard the owner yelling at one of the staff for not wearing enough makeup to work and for having a visible bruise which she said she got because she fell (it was on her back). Ended up leaving and will not be going back, especially after what employees and Ex employees have said about their experiences.
#    BUSINESS CATEGORY: Coffee shop, Cafe, Coffee stand, Coffee store
#    RATING: 1
#    CURRENT LABEL: acceptable review
#    SUGGESTED LABEL: irrelevant content
#    REASON: Content not related to business type (Coffee shop, Cafe, Coffee stand, Coffee store)
# ------------------------------------------------------------
#
# 5341. TEXT: This place only cares about money not about the animal. Don't go to them! if I could give 0 stars I would.
#    BUSINESS CATEGORY: Veterinarian, Animal hospital, Emergency veterinarian service, Veterinary pharmacy
#    RATING: 1
#    CURRENT LABEL: acceptable review
#    SUGGESTED LABEL: irrelevant content
#    REASON: Content not related to business type (Veterinarian, Animal hospital, Emergency veterinarian service, Veterinary pharmacy)
# ------------------------------------------------------------
# ================================================================================
# SUGGESTED LABEL: LOW QUALITY REVIEW  (showing up to 10 mismatches)
# ================================================================================
#
# 10. TEXT: nice
#    BUSINESS CATEGORY: Grocery store, Grocery delivery service
#    RATING: 5
#    CURRENT LABEL: acceptable review
#    SUGGESTED LABEL: low quality review
#    REASON: Very short review with minimal content
# ------------------------------------------------------------
#
# 15. TEXT: Yummy
#    BUSINESS CATEGORY: Hamburger restaurant
#    RATING: 5
#    CURRENT LABEL: acceptable review
#    SUGGESTED LABEL: low quality review
#    REASON: Very short review with minimal content
# ------------------------------------------------------------
#
# 17. TEXT: Yum
#    BUSINESS CATEGORY: Mexican restaurant, Restaurant
#    RATING: 5
#    CURRENT LABEL: acceptable review
#    SUGGESTED LABEL: low quality review
#    REASON: Very short review with minimal content
# ------------------------------------------------------------
#
# 20. TEXT: 👍👍
#    BUSINESS CATEGORY: Department store, Clothing store, Furniture store, Jewelry store, Shoe store
#    RATING: 5
#    CURRENT LABEL: irrelevant content
#    SUGGESTED LABEL: low quality review
#    REASON: Very short review with minimal content
# ------------------------------------------------------------
#
# 31. TEXT: Great
#    BUSINESS CATEGORY: Cannabis store
#    RATING: 5
#    CURRENT LABEL: acceptable review
#    SUGGESTED LABEL: low quality review
#    REASON: Very short review with minimal content
# ------------------------------------------------------------
#
# 45. TEXT: Yummm
#    BUSINESS CATEGORY: Coffee shop, Cafe, Juice shop, Tea house
#    RATING: 5
#    CURRENT LABEL: acceptable review
#    SUGGESTED LABEL: low quality review
#    REASON: Very short review with minimal content
# ------------------------------------------------------------
#
# 78. TEXT: Tasty
#    BUSINESS CATEGORY: Fast food restaurant, American restaurant, Chicken restaurant, Hamburger restaurant, Sandwich shop
#    RATING: 5
#    CURRENT LABEL: acceptable review
#    SUGGESTED LABEL: low quality review
#    REASON: Very short review with minimal content
# ------------------------------------------------------------
#
# 96. TEXT: Yummy
#    BUSINESS CATEGORY: Hamburger restaurant, American restaurant, Diner, Fast food restaurant, Lunch restaurant, Restaurant
#    RATING: 5
#    CURRENT LABEL: acceptable review
#    SUGGESTED LABEL: low quality review
#    REASON: Very short review with minimal content
# ------------------------------------------------------------
#
# 98. TEXT: By
#    BUSINESS CATEGORY: Hair salon, Beauty salon
#    RATING: 5
#    CURRENT LABEL: acceptable review
#    SUGGESTED LABEL: low quality review
#    REASON: Very short review with minimal content
# ------------------------------------------------------------
#
# 104. TEXT: Nice
#    BUSINESS CATEGORY: Shopping mall, Clothing store, Restaurant
#    RATING: 3
#    CURRENT LABEL: acceptable review
#    SUGGESTED LABEL: low quality review
#    REASON: Very short review with minimal content
# ------------------------------------------------------------
# ================================================================================
# SUGGESTED LABEL: RANT WITHOUT VISIT  (showing up to 10 mismatches)
# ================================================================================
#
# 410. TEXT: Great Italian food with a moderate price. I've yet to try something I don't enjoy and the staff is always polite. If you've never been here, it's worth a stop in.
#    BUSINESS CATEGORY: Italian restaurant
#    RATING: 5
#    CURRENT LABEL: low quality review
#    SUGGESTED LABEL: rant without visit
#    REASON: Appears to complain without visiting
# ------------------------------------------------------------
#
# 431. TEXT: Never been here before but found a cool place with good food. My bowl looks like a salad from this picture but under this is shredded chicken, beans, rice then the lettuce, cheese, etc. you see. It was good!  My hubby liked his burrito too. The chips were OK and the guacamole was weird...they said they usually make their own but not many reasonable avocado options right now so they took this back. Ended the meal with this sweet cheesecake. The place was clean, set up for social distancing and the staff were helpful.
#    BUSINESS CATEGORY: Mexican restaurant, Latin American restaurant
#    RATING: 4
#    CURRENT LABEL: acceptable review
#    SUGGESTED LABEL: rant without visit
#    REASON: Appears to complain without visiting
# ------------------------------------------------------------
#
# 1758. TEXT: The food here is very good, with its quality reflected in its prices. That being said, the prices are only a little bit higher than most small Chinese restaurants you would go to. I find the atmosphere very relaxing and comfortable with the staff always being polite and helpful. Drink refills are offered around the time I need one, and to my surprise towards the end of a meal I never feel like they're rushing me out. On my last visit here I came on my girlfriend's birthday, not expecting anything for it being that restaurants like this rarely sing or give free desserts.  And although it was at the end of the night and somewhat close to closing we were both surprised when our waitress came out singing and giving her a free serving of Chinese donuts with a candle sticking out of one. If you've never been here before I can't recommend the Orange Beef enough. It is a standout item of the menu. And if you plan on treating yourself, definitely order yourself the cream cheese wonton appetizer. Next time we visit we are planning on trying the drink menu, on this last trip the anticipation for the food distracted us.
#    BUSINESS CATEGORY: Chinese restaurant, Restaurant
#    RATING: 5
#    CURRENT LABEL: acceptable review
#    SUGGESTED LABEL: rant without visit
#    REASON: Appears to complain without visiting
# ------------------------------------------------------------
#
# 2247. TEXT: Nice place I have never been here before . Relaxing and fishing.
#    BUSINESS CATEGORY: Park, Tourist attraction
#    RATING: 5
#    CURRENT LABEL: nan
#    SUGGESTED LABEL: rant without visit
#    REASON: Appears to complain without visiting
# ------------------------------------------------------------
#
# 3210. TEXT: This place is fabulous 👌!! How is it that we have never been here before. My husband's last name is Salazar and he said the food is like the food he grew up on. I don't know how you could get any fresher food - the salsa is made fresh at the table and they even make their own tortillas. Maybe I should say the food is terrible so I can keep this restaurant as my own little secret, but I can't do that. If you want authentic Mexican food - you have to come here!!!! Oh, by the way - the people here are great. They are so friendly. They do get pretty busy so I would advise making reservations.
#    BUSINESS CATEGORY: Mexican restaurant, Restaurant
#    RATING: 5
#    CURRENT LABEL: nan
#    SUGGESTED LABEL: rant without visit
#    REASON: Appears to complain without visiting
# ------------------------------------------------------------
#
# 3383. TEXT: How have never been here before! Excellent food. Excellent service. The fruit burrito was AMAZING!! and let me say the coffee was also perfect, nice and strong. Definitely will be back.
#    BUSINESS CATEGORY: Mexican restaurant, Bar, Ice cream shop, Takeout Restaurant, Salad shop, Sandwich shop, Soup restaurant, Taco restaurant, Vegan restaurant, Vegetarian restaurant
#    RATING: 5
#    CURRENT LABEL: nan
#    SUGGESTED LABEL: rant without visit
#    REASON: Appears to complain without visiting
# ------------------------------------------------------------
#
# 3930. TEXT: I called this bar because on 2/25/2020 at 1:53 PM my card was charged 5 dollars. I have never been here.  I was at home in Drexel heights sick at the time so I messaged the bar this morning. No response. I called right now and a bartender answered. She said there was no manager available,  could she help me. While I was explaining to her what happened, she started talking to someone else. I said I would like to talk to someone that had time to listen. She got an attitude and said call my bank and hung up on me. I am now not only going to call my bank, but I am am also going to get a lawyer. They had to have manually entered my card number. Rather than looking to see who was responsible since I had a date and time, she got an attitude. All she had to do was be a decent human being, and she wanted to have an attitude. Watch your bank accounts people,, this place Is shady.
#    BUSINESS CATEGORY: Bar & grill, Restaurant
#    RATING: 1
#    CURRENT LABEL: acceptable review
#    SUGGESTED LABEL: rant without visit
#    REASON: Appears to complain without visiting
# ------------------------------------------------------------
#
# 5498. TEXT: Dr. Jessica V. Is probably one of the best dentist in the valley that I have ever been to. I've always had my issues going to the dentist to get major work done and she explained everything in detail and made my smile on my two front teeth back to normal. The coloration match for the feelings were perfect and pristine as if they were my original  two front teeth. She definitely has the Magic Touch when it comes to dental perfection. Stacy her assistant was a pleasure to have working also on my teeth. They both made me feel very comfortable after having nothing done other than cleanings for quite a few years. And if you're ever in need of a root canal she is the only one I would recommend to have do it, it was my first root canal and I don't know why people say they're so bad because it was painless having her do the work on it and never felt uncomfortable or in pain. So if you're in need of any dental work, your go-to dentist should be Dr. Jessica V at Desert Dentistry in Ahwatukee. Ray L.
#    BUSINESS CATEGORY: Dental clinic, Cosmetic dentist, Dental implants periodontist, Dentist, Emergency dental service, Orthodontist
#    RATING: 5
#    CURRENT LABEL: acceptable review
#    SUGGESTED LABEL: rant without visit
#    REASON: Appears to complain without visiting
# ------------------------------------------------------------
#
# 5930. TEXT: I haven't a clue. Never been here.
#    BUSINESS CATEGORY: Arena
#    RATING: 5
#    CURRENT LABEL: nan
#    SUGGESTED LABEL: rant without visit
#    REASON: Appears to complain without visiting
# ------------------------------------------------------------
