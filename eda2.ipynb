# %%
import pandas as pd
import numpy as np
import re
import ast

def analyze_specific_example():
    """Analyze the specific gmap_id example you provided"""
    
    # The specific example data
    gmap_id = "0x872b46a9afb11747:0xbab4f9c1c4625e5e"
    name = "jay Jaysam2415"
    rating = 1
    resp_raw = "{'text': 'Jay, we strive to provide excellent service to our customers. We do not show that we have ever done business with you and you have never been a customer at our shop. I do see that you have recently reviewed 3 other transmission shops around the valley. We would appreciate the opportunity to clear up any misunderstandings and ask that you please contact our shop at your convenience.', 'time': 1559153757964.0}"
    text = "All I can say is SMH about this place be careful"
    business_category = "Transmission shop, Auto machine shop, Auto repair shop, Auto tune up service, Brake shop, Car repair and maintenance"
    
    print("="*80)
    print("SPECIFIC EXAMPLE ANALYSIS")
    print("="*80)
    
    print(f"GMAP_ID: {gmap_id}")
    print(f"REVIEWER NAME: {name}")
    print(f"RATING: {rating}")
    print(f"REVIEW TEXT: {text}")
    print(f"BUSINESS CATEGORY: {business_category}")
    
    # Parse business response
    try:
        resp_dict = ast.literal_eval(resp_raw)
        business_response = resp_dict.get('text', '')
    except:
        business_response = ""
    
    print(f"BUSINESS RESPONSE: {business_response}")
    
    print(f"\n" + "-"*60)
    print("ANALYSIS BREAKDOWN:")
    print("-"*60)
    
    # Run analysis using the main functions
    analysis = analyze_single_review(text, "Unknown", business_category, rating, True, resp_raw)
    
    print(f"Review Length: {len(text)} characters")
    print(f"Rating: {rating}/5 (negative)")
    print(f"Has Business Response: Yes")
    
    print(f"\nDetailed Pattern Analysis:")
    print(f"- Advertisement patterns: {has_advertisement_patterns(text)}")
    print(f"- Irrelevant content patterns: {has_irrelevant_patterns(text, business_category)}")
    print(f"- Rant without visit patterns: {has_rant_no_visit_patterns(text, rating, True, business_response)}")
    print(f"- Is clean review: {is_actually_clean_review(text, business_category, business_response)}")
    
    print(f"\nFINAL CLASSIFICATION:")
    print(f"Suggested Label: {analysis['suggested_label']}")
    print(f"Confidence: {analysis['confidence']}")
    print(f"Reasoning: {analysis['reason']}")
    
    print(f"\nKEY EVIDENCE:")
    print(f"Business explicitly states: 'you have never been a customer at our shop'")
    print(f"This provides definitive proof that the reviewer did not visit/use the service")
    print(f"Combined with negative review = clear 'Rant without visit' violation")
    
    return analysis

def comprehensive_label_validation(df):
    """Validate all classification categories for accuracy"""
    
    print("="*80)
    print("COMPREHENSIVE LABEL VALIDATION ANALYSIS")
    print("="*80)
    
    print("\n1. OVERALL LABEL DISTRIBUTION:")
    distribution = df['classification'].value_counts()
    print(distribution)
    
    validation_results = {}
    all_prompting_issues = []
    
    categories = df['classification'].unique()
    
    for category in categories:
        print(f"\n{'='*60}")
        print(f"ANALYZING: {category.upper()}")
        print(f"{'='*60}")
        
        category_data = df[df['classification'] == category]
        total_in_category = len(category_data)
        sample_size = len(category_data)  # Use ALL data
        sample_data = category_data  # No sampling
        
        correct_count = 0
        mislabeled_count = 0
        correct_examples = []
        mislabeled_examples = []
        
        for idx, row in sample_data.iterrows():
            text = str(row['text'])
            business_category = str(row.get('category_str', 'Unknown'))
            rating = row.get('rating', 'N/A')
            has_response = str(row.get('resp', '')).strip() not in ['', 'nan', 'None']
            
            resp_text = row.get('resp', '')
            analysis = analyze_single_review(text, category, business_category, rating, has_response, resp_text)
            
            if analysis['is_correct']:
                correct_count += 1
                correct_examples.append({
                    'text': text,
                    'business_category': business_category,
                    'rating': rating,
                    'has_response': has_response,
                    'reason': analysis['reason']
                })
            else:
                mislabeled_count += 1
                mislabeled_examples.append({
                    'text': text,
                    'business_category': business_category,
                    'rating': rating,
                    'has_response': has_response,
                    'suggested_label': analysis['suggested_label'],
                    'reason': analysis['reason']
                })
        
        accuracy = (correct_count / sample_size) * 100
        
        print(f"Total samples in category: {total_in_category}")
        print(f"CATEGORY SUMMARY:")
        print(f"Total samples in dataset: {total_in_category}")
        print(f"Analyzed sample: {sample_size}")
        print(f"Correct labels: {correct_count}/{sample_size} ({accuracy:.1f}%)")
        print(f"Mislabeled: {mislabeled_count}/{sample_size} ({100-accuracy:.1f}%)")
        
        print(f"\n--- CORRECTLY LABELED EXAMPLES ---")
        for i, example in enumerate(correct_examples[:10], 1):
            print(f"\n{i}. CORRECT EXAMPLE:")
            print(f"   TEXT: {example['text']}")
            print(f"   BUSINESS CATEGORY: {example['business_category']}")
            print(f"   RATING: {example['rating']}")
            print(f"   HAS BUSINESS RESPONSE: {example['has_response']}")
            print(f"   WHY CORRECT: {example['reason']}")
            print("-" * 60)
        
        print(f"\n--- MISLABELED EXAMPLES ---")
        for i, example in enumerate(mislabeled_examples[:10], 1):
            print(f"\n{i}. MISLABELED EXAMPLE:")
            print(f"   TEXT: {example['text']}")
            print(f"   BUSINESS CATEGORY: {example['business_category']}")
            print(f"   RATING: {example['rating']}")
            print(f"   HAS BUSINESS RESPONSE: {example['has_response']}")
            print(f"   CURRENT LABEL: {category}")
            print(f"   SUGGESTED LABEL: {example['suggested_label']}")
            print(f"   WHY MISLABELED: {example['reason']}")
            print("-" * 60)
        
        prompting_issue = analyze_prompting_issues(category, accuracy, correct_examples, mislabeled_examples)
        all_prompting_issues.append(prompting_issue)
        
        validation_results[category] = {
            'accuracy': accuracy,
            'correct_count': correct_count,
            'mislabeled_count': mislabeled_count,
            'total_samples': total_in_category
        }
    
    create_consolidated_prompting_strategy(all_prompting_issues, validation_results)
    
    return validation_results

def analyze_single_review(text, current_label, business_category, rating, has_response, resp_text=""):
    """Enhanced analysis including business response text"""
    
    # Extract response text if available
    business_response = ""
    if has_response and resp_text and str(resp_text) != 'nan':
        try:
            if isinstance(resp_text, str) and resp_text.startswith('{'):
                resp_dict = ast.literal_eval(resp_text)
                business_response = resp_dict.get('text', '')
            elif isinstance(resp_text, dict):
                business_response = resp_text.get('text', '')
            else:
                business_response = str(resp_text)
        except:
            business_response = str(resp_text)
    
    has_ads = has_advertisement_patterns(text)
    has_irrelevant = has_irrelevant_patterns(text, business_category)
    has_rant = has_rant_no_visit_patterns(text, rating, has_response, business_response)
    is_clean = is_actually_clean_review(text, business_category, business_response)
    
    if has_ads:
        suggested = "Advertisement"
        confidence = "High"
        reason = "Contains promotional content or links"
    elif has_irrelevant:
        suggested = "Irrelevant content"
        confidence = "High"
        reason = f"Content not related to business type ({business_category})"
    elif has_rant:
        suggested = "Rant without visit"
        confidence = "High" if "never been a customer" in business_response.lower() else "Medium"
        reason = "Business confirms no customer relationship" if "never been a customer" in business_response.lower() else "Appears to complain without visiting"
    elif is_clean:
        suggested = "Acceptable review"
        confidence = "Medium"
        reason = "Legitimate review about business experience"
    else:
        if len(text.strip()) < 10:
            suggested = "Low quality review"
            confidence = "Low"
            reason = "Very short review with minimal content"
        else:
            suggested = "Acceptable review"
            confidence = "Low"
            reason = "Cannot determine clear policy violation"
    
    return {
        'suggested_label': suggested,
        'confidence': confidence,
        'reason': reason,
        'is_correct': suggested.lower().replace(' ', '').replace('_', '') == current_label.lower().replace(' ', '').replace('_', '')
    }

def has_advertisement_patterns(text):
    """Much stricter advertisement detection - only clear promotional content"""
    strict_ad_patterns = [
        r'www\.\w+|http[s]?://\w+',  # Actual URLs
        r'\b(use code|promo code|coupon code)\s+\w+',  # Specific promo codes
        r'\b(call|text|contact)\s+(us\s+)?at\s*\d{3}',  # Contact with phone numbers
        r'\b(visit our|check our|go to our)\s+(website|site)',  # Direct website promotion
        r'\b(get|save)\s+\d+%\s+(off|discount)',  # Specific discount offers
    ]
    return any(re.search(pattern, text.lower()) for pattern in strict_ad_patterns)

def has_irrelevant_patterns(text, business_category):
    """Much stricter irrelevant content detection - must be clearly off-topic"""
    business_type = business_category.lower() if business_category else ""
    text_lower = text.lower()
    
    # Only flag if explicitly discussing unrelated items as the main topic
    clear_irrelevant_patterns = [
        r'\b(not about|unrelated to|off topic)\b',
        r'(wrong place|different location|thought this was)',
        r'(my new phone|bought a laptop|car problems).*but.*place',
    ]
    
    if any(re.search(pattern, text_lower) for pattern in clear_irrelevant_patterns):
        return True
    
    # Food businesses - only flag if clearly about non-food as main topic
    if any(word in business_type for word in ['restaurant', 'food', 'cafe', 'bar']):
        if re.search(r'(this review is about my|talking about my|discussing my)\s+(phone|car|laptop)', text_lower):
            return True
    
    return False

def has_rant_no_visit_patterns(text, rating, has_response, business_response_text=""):
    """Enhanced rant detection using business response confirmation"""
    
    # Check business response for confirmation of no visit
    if business_response_text and business_response_text.strip():
        business_confirms_no_visit = [
            r'never been a customer',
            r'have not done business with you',
            r'you have never visited',
            r'no record of your visit',
            r'never provided service to you',
            r'do not show.*ever done business with you'
        ]
        
        if any(re.search(pattern, business_response_text.lower()) for pattern in business_confirms_no_visit):
            return True
    
    # Original text-based detection
    explicit_no_visit_patterns = [
        r'\b(never been here|haven\'?t visited this place|didn\'?t go to this place)\b',
        r'\b(never went to this|haven\'?t been to this)\b',
        r'\b(heard from others|someone told me|people say)\b.*\b(terrible|awful|bad|horrible)\b',
        r'\b(based on what I heard|from what I\'ve heard)\b',
    ]
    
    text_indicates_no_visit = any(re.search(pattern, text.lower()) for pattern in explicit_no_visit_patterns)
    
    # Additional signals: Very short negative review + low rating + business denial
    is_very_short_negative = len(text.strip()) < 30 and rating is not None and isinstance(rating, (int, float)) and rating <= 2
    business_denies_service = any(re.search(pattern, business_response_text.lower()) for pattern in [r'never been a customer', r'do not show.*ever done business']) if business_response_text else False
    
    return text_indicates_no_visit or (is_very_short_negative and business_denies_service)

def is_actually_clean_review(text, business_category, business_response):
    """Most reviews should be clean unless clear violations exist"""
    return (len(text.strip()) > 5 and
            not has_advertisement_patterns(text) and
            not has_irrelevant_patterns(text, business_category) and
            not has_rant_no_visit_patterns(text, None, None, business_response))

def analyze_prompting_issues(category, accuracy, correct_examples, mislabeled_examples):
    """Analyze prompting issues for later consolidation"""
    
    issues = {
        'category': category,
        'accuracy': accuracy,
        'main_problem': '',
        'specific_fixes': []
    }
    
    if category == "Advertisement" and accuracy < 80:
        issues['main_problem'] = "Confusing customer recommendations with advertisements"
        issues['specific_fixes'] = [
            "Only flag reviews with actual URLs, promo codes, or phone numbers",
            "Don't flag positive customer experiences as ads",
            "Look for business self-promotion, not customer enthusiasm"
        ]
    elif category == "Low quality review" and accuracy < 50:
        issues['main_problem'] = "Flagging legitimate detailed reviews as low quality"
        issues['specific_fixes'] = [
            "Only flag extremely short reviews (under 10 characters)",
            "Don't flag reviews with specific experiences as low quality",
            "Focus on meaningless reviews like single words"
        ]
    elif category == "Irrelevant content" and accuracy < 80:
        issues['main_problem'] = "Flagging relevant content as irrelevant"
        issues['specific_fixes'] = [
            "Food/kitchen/service content IS relevant to restaurants",
            "Only flag if review explicitly discusses unrelated topics",
            "Context matters - enthusiastic food reviews are relevant"
        ]
    elif category == "Rant without visit" and accuracy < 80:
        issues['main_problem'] = "Flagging reviews with clear visit evidence as non-visitor rants"
        issues['specific_fixes'] = [
            "Look for explicit 'never been here' language",
            "Reviews mentioning staff interaction show visits",
            "Detailed service descriptions indicate actual experience",
            "Use business responses that deny customer relationship as strong evidence"
        ]
    
    return issues

def create_consolidated_prompting_strategy(all_issues, validation_results):
    """Create consolidated prompting improvements at the end"""
    
    print(f"\n{'='*80}")
    print("CONSOLIDATED PROMPTING IMPROVEMENT STRATEGY")
    print(f"{'='*80}")
    
    print("\nACCURACY SUMMARY BY CATEGORY:")
    for category, results in validation_results.items():
        print(f"{category:25}: {results['accuracy']:5.1f}% accurate")
    
    print("\nMAJOR ISSUES IDENTIFIED:")
    for issue in all_issues:
        if issue['main_problem']:
            print(f"\n{issue['category']}:")
            print(f"  Problem: {issue['main_problem']}")
            for fix in issue['specific_fixes']:
                print(f"  Fix: {fix}")
    
    print(f"\nCORRECTED PROMPT STRATEGY:")
    print("""
TASK: Classify this review for policy violations using STRICT criteria.

CONTEXT:
Business: [Business Name]
Category: [Business Category] 
Rating: [1-5 stars]
Review: "[Review Text]"
Business Response: "[If available]"

STRICT CLASSIFICATION RULES:

1. ADVERTISEMENT - Only if contains:
   - Actual website URLs (www.site.com, http://)
   - Specific promo codes ("use code SAVE20")
   - Phone numbers with "call us at"
   - Direct business promotion language
   NOT customer enthusiasm or recommendations

2. IRRELEVANT CONTENT - Only if review explicitly discusses:
   - Topics completely unrelated to business type
   - Wrong business entirely
   - Personal matters unrelated to the service
   NOT food reviews for restaurants or service reviews for services

3. RANT WITHOUT VISIT - Only if explicitly states OR business confirms:
   - "Never been here but..."
   - "Haven't visited but heard..."
   - "Based on what others told me..."
   - Business responds "never been a customer" or similar
   NOT detailed negative experiences (these show actual visits)

4. ACCEPTABLE REVIEW - Default for legitimate customer experiences:
   - Any review discussing actual business experience
   - Positive, negative, or neutral customer feedback
   - Reviews matching business category appropriately

DEFAULT: When in doubt, classify as ACCEPTABLE REVIEW
Most customer reviews should be acceptable unless clear violations exist.

ANSWER: [Category]
REASONING: [Why this specific classification]
""")

# Main execution
if __name__ == "__main__":
    # First analyze the specific example
    print("STEP 1: ANALYZING SPECIFIC EXAMPLE")
    analyze_specific_example()
    
    print("\n\nSTEP 2: FULL DATASET VALIDATION")
    df = pd.read_csv('classified_reviews_cleaned.csv')
    validation_results = comprehensive_label_validation(df)
    
    print(f"\nValidation complete. The specific example demonstrates how business responses can confirm 'Rant without visit' violations.")
# Out:
# STEP 1: ANALYZING SPECIFIC EXAMPLE
# ================================================================================
# SPECIFIC EXAMPLE ANALYSIS
# ================================================================================
# GMAP_ID: 0x872b46a9afb11747:0xbab4f9c1c4625e5e
# REVIEWER NAME: jay Jaysam2415
# RATING: 1
# REVIEW TEXT: All I can say is SMH about this place be careful
# BUSINESS CATEGORY: Transmission shop, Auto machine shop, Auto repair shop, Auto tune up service, Brake shop, Car repair and maintenance
# BUSINESS RESPONSE: Jay, we strive to provide excellent service to our customers. We do not show that we have ever done business with you and you have never been a customer at our shop. I do see that you have recently reviewed 3 other transmission shops around the valley. We would appreciate the opportunity to clear up any misunderstandings and ask that you please contact our shop at your convenience.
#
# ------------------------------------------------------------
# ANALYSIS BREAKDOWN:
# ------------------------------------------------------------
# Review Length: 48 characters
# Rating: 1/5 (negative)
# Has Business Response: Yes
#
# Detailed Pattern Analysis:
# - Advertisement patterns: False
# - Irrelevant content patterns: False
# - Rant without visit patterns: True
# - Is clean review: False
#
# FINAL CLASSIFICATION:
# Suggested Label: Rant without visit
# Confidence: High
# Reasoning: Business confirms no customer relationship
#
# KEY EVIDENCE:
# Business explicitly states: 'you have never been a customer at our shop'
# This provides definitive proof that the reviewer did not visit/use the service
# Combined with negative review = clear 'Rant without visit' violation
#
#
# STEP 2: FULL DATASET VALIDATION
# ================================================================================
# COMPREHENSIVE LABEL VALIDATION ANALYSIS
# ================================================================================
#
# 1. OVERALL LABEL DISTRIBUTION:
# classification
# Acceptable review     8419
# Low quality review    2536
# Rant without visit     867
# Irrelevant content     151
# Advertisement           27
# Name: count, dtype: int64
#
# ============================================================
# ANALYZING: ACCEPTABLE REVIEW
# ============================================================
# Total samples in category: 8419
# CATEGORY SUMMARY:
# Total samples in dataset: 8419
# Analyzed sample: 8419
# Correct labels: 8281/8419 (98.4%)
# Mislabeled: 138/8419 (1.6%)
#
# --- CORRECTLY LABELED EXAMPLES ---
#
# 1. CORRECT EXAMPLE:
#    TEXT: Great people. A one stop store for anything you might need.
#    BUSINESS CATEGORY: Grocery store, Propane supplier
#    RATING: 5
#    HAS BUSINESS RESPONSE: False
#    WHY CORRECT: Legitimate review about business experience
# ------------------------------------------------------------
#
# 2. CORRECT EXAMPLE:
#    TEXT: Always spend too much!
#    BUSINESS CATEGORY: Warehouse store, Department store
#    RATING: 5
#    HAS BUSINESS RESPONSE: False
#    WHY CORRECT: Legitimate review about business experience
# ------------------------------------------------------------
#
# 3. CORRECT EXAMPLE:
#    TEXT: I like shopping here
#    BUSINESS CATEGORY: Sporting goods store, Boat dealer, Camping store, Gun shop
#    RATING: 5
#    HAS BUSINESS RESPONSE: False
#    WHY CORRECT: Legitimate review about business experience
# ------------------------------------------------------------
#
# 4. CORRECT EXAMPLE:
#    TEXT: Fine if you want to browse for video games. They pay very little for used hardware/games and they charge a lot for used hardware/games.
#    BUSINESS CATEGORY: Video game store, Cell phone store, Collectibles store, Electronics store
#    RATING: 3
#    HAS BUSINESS RESPONSE: False
#    WHY CORRECT: Legitimate review about business experience
# ------------------------------------------------------------
#
# 5. CORRECT EXAMPLE:
#    TEXT: Sushi was amazing, very fair prices as well.  Who doesn't love revolving sushi.
#    BUSINESS CATEGORY: Sushi restaurant
#    RATING: 5
#    HAS BUSINESS RESPONSE: False
#    WHY CORRECT: Legitimate review about business experience
# ------------------------------------------------------------
#
# 6. CORRECT EXAMPLE:
#    TEXT: Kohl's is right behind IHOP so I get a great meal and shopping too
#    BUSINESS CATEGORY: Restaurant, American restaurant, Breakfast restaurant, Family restaurant
#    RATING: 5
#    HAS BUSINESS RESPONSE: False
#    WHY CORRECT: Legitimate review about business experience
# ------------------------------------------------------------
#
# 7. CORRECT EXAMPLE:
#    TEXT: Fishy, greasy, not real fresh food, then short Asian guy, with glasses said:"You are only giving me $2, for a tip, there are two of you". Thisvis a self serve buffet, a small tip is enough. All the kid did was ask us what soft drink we wanted
#    BUSINESS CATEGORY: Japanese restaurant, Asian restaurant, Bar, Bar & grill, Buffet restaurant, Chinese restaurant
#    RATING: 1
#    HAS BUSINESS RESPONSE: False
#    WHY CORRECT: Legitimate review about business experience
# ------------------------------------------------------------
#
# 8. CORRECT EXAMPLE:
#    TEXT: Love this place
#    BUSINESS CATEGORY: Food bank, Non-profit organization
#    RATING: 5
#    HAS BUSINESS RESPONSE: False
#    WHY CORRECT: Legitimate review about business experience
# ------------------------------------------------------------
#
# 9. CORRECT EXAMPLE:
#    TEXT: In the zone Baby
#    BUSINESS CATEGORY: Auto parts store, Car accessories store, Car battery store, Tool rental service
#    RATING: 5
#    HAS BUSINESS RESPONSE: True
#    WHY CORRECT: Legitimate review about business experience
# ------------------------------------------------------------
#
# 10. CORRECT EXAMPLE:
#    TEXT: Very nice and clean!
#    BUSINESS CATEGORY: Grocery store, Grocery delivery service
#    RATING: 5
#    HAS BUSINESS RESPONSE: False
#    WHY CORRECT: Legitimate review about business experience
# ------------------------------------------------------------
#
# --- MISLABELED EXAMPLES ---
#
# 1. MISLABELED EXAMPLE:
#    TEXT: Darts
#    BUSINESS CATEGORY: Bar
#    RATING: 5
#    HAS BUSINESS RESPONSE: True
#    CURRENT LABEL: Acceptable review
#    SUGGESTED LABEL: Low quality review
#    WHY MISLABELED: Very short review with minimal content
# ------------------------------------------------------------
#
# 2. MISLABELED EXAMPLE:
#    TEXT: Cool
#    BUSINESS CATEGORY: Supermarket, Bakery, Butcher shop, Deli, Grocery store, Produce market
#    RATING: 5
#    HAS BUSINESS RESPONSE: False
#    CURRENT LABEL: Acceptable review
#    SUGGESTED LABEL: Low quality review
#    WHY MISLABELED: Very short review with minimal content
# ------------------------------------------------------------
#
# 3. MISLABELED EXAMPLE:
#    TEXT: Nice
#    BUSINESS CATEGORY: Pizza restaurant, Delivery Restaurant
#    RATING: 5
#    HAS BUSINESS RESPONSE: False
#    CURRENT LABEL: Acceptable review
#    SUGGESTED LABEL: Low quality review
#    WHY MISLABELED: Very short review with minimal content
# ------------------------------------------------------------
#
# 4. MISLABELED EXAMPLE:
#    TEXT: Great
#    BUSINESS CATEGORY: Laundromat
#    RATING: 5
#    HAS BUSINESS RESPONSE: True
#    CURRENT LABEL: Acceptable review
#    SUGGESTED LABEL: Low quality review
#    WHY MISLABELED: Very short review with minimal content
# ------------------------------------------------------------
#
# 5. MISLABELED EXAMPLE:
#    TEXT: A-ok
#    BUSINESS CATEGORY: Italian restaurant
#    RATING: 4
#    HAS BUSINESS RESPONSE: False
#    CURRENT LABEL: Acceptable review
#    SUGGESTED LABEL: Low quality review
#    WHY MISLABELED: Very short review with minimal content
# ------------------------------------------------------------
#
# 6. MISLABELED EXAMPLE:
#    TEXT: Love
#    BUSINESS CATEGORY: Seafood restaurant, Fast food restaurant, Fish & chips restaurant, Restaurant
#    RATING: 5
#    HAS BUSINESS RESPONSE: False
#    CURRENT LABEL: Acceptable review
#    SUGGESTED LABEL: Low quality review
#    WHY MISLABELED: Very short review with minimal content
# ------------------------------------------------------------
#
# 7. MISLABELED EXAMPLE:
#    TEXT: 👍
#    BUSINESS CATEGORY: Casino, Tourist attraction
#    RATING: 4
#    HAS BUSINESS RESPONSE: False
#    CURRENT LABEL: Acceptable review
#    SUGGESTED LABEL: Low quality review
#    WHY MISLABELED: Very short review with minimal content
# ------------------------------------------------------------
#
# 8. MISLABELED EXAMPLE:
#    TEXT: Yum
#    BUSINESS CATEGORY: Fast food restaurant, Hamburger restaurant, Restaurant
#    RATING: 5
#    HAS BUSINESS RESPONSE: False
#    CURRENT LABEL: Acceptable review
#    SUGGESTED LABEL: Low quality review
#    WHY MISLABELED: Very short review with minimal content
# ------------------------------------------------------------
#
# 9. MISLABELED EXAMPLE:
#    TEXT: Yummy
#    BUSINESS CATEGORY: Breakfast restaurant, American restaurant, Bakery, Brunch restaurant, Cafe, Diner, Restaurant
#    RATING: 5
#    HAS BUSINESS RESPONSE: False
#    CURRENT LABEL: Acceptable review
#    SUGGESTED LABEL: Low quality review
#    WHY MISLABELED: Very short review with minimal content
# ------------------------------------------------------------
#
# 10. MISLABELED EXAMPLE:
#    TEXT: Yum
#    BUSINESS CATEGORY: Fast food restaurant, Chicken restaurant, Hamburger restaurant, Ice cream shop, Restaurant
#    RATING: 5
#    HAS BUSINESS RESPONSE: False
#    CURRENT LABEL: Acceptable review
#    SUGGESTED LABEL: Low quality review
#    WHY MISLABELED: Very short review with minimal content
# ------------------------------------------------------------
#
# ============================================================
# ANALYZING: LOW QUALITY REVIEW
# ============================================================
# Total samples in category: 2536
# CATEGORY SUMMARY:
# Total samples in dataset: 2536
# Analyzed sample: 2536
# Correct labels: 40/2536 (1.6%)
# Mislabeled: 2496/2536 (98.4%)
#
# --- CORRECTLY LABELED EXAMPLES ---
#
# 1. CORRECT EXAMPLE:
#    TEXT: Nice
#    BUSINESS CATEGORY: Massage therapist, Holistic medicine practitioner, Massage spa
#    RATING: 5
#    HAS BUSINESS RESPONSE: True
#    WHY CORRECT: Very short review with minimal content
# ------------------------------------------------------------
#
# 2. CORRECT EXAMPLE:
#    TEXT: Yum
#    BUSINESS CATEGORY: Fast food restaurant, Breakfast restaurant, Burrito restaurant, Lunch restaurant, Takeout Restaurant, Mexican restaurant, Restaurant, Taco restaurant, Tex-Mex restaurant, Vegetarian restaurant
#    RATING: 4
#    HAS BUSINESS RESPONSE: False
#    WHY CORRECT: Very short review with minimal content
# ------------------------------------------------------------
#
# 3. CORRECT EXAMPLE:
#    TEXT: Good
#    BUSINESS CATEGORY: Department store, Clothing store, Craft store, Discount store, Electronics store, Grocery store, Home goods store, Sporting goods store, Supermarket, Toy store
#    RATING: 5
#    HAS BUSINESS RESPONSE: False
#    WHY CORRECT: Very short review with minimal content
# ------------------------------------------------------------
#
# 4. CORRECT EXAMPLE:
#    TEXT: Yep
#    BUSINESS CATEGORY: Shopping mall
#    RATING: 4
#    HAS BUSINESS RESPONSE: False
#    WHY CORRECT: Very short review with minimal content
# ------------------------------------------------------------
#
# 5. CORRECT EXAMPLE:
#    TEXT: Nice
#    BUSINESS CATEGORY: Gym
#    RATING: 3
#    HAS BUSINESS RESPONSE: False
#    WHY CORRECT: Very short review with minimal content
# ------------------------------------------------------------
#
# 6. CORRECT EXAMPLE:
#    TEXT: Duh.
#    BUSINESS CATEGORY: Airport
#    RATING: 5
#    HAS BUSINESS RESPONSE: False
#    WHY CORRECT: Very short review with minimal content
# ------------------------------------------------------------
#
# 7. CORRECT EXAMPLE:
#    TEXT: Ok
#    BUSINESS CATEGORY: Chicken wings restaurant, American restaurant, Bar & grill, Restaurant, Sports bar
#    RATING: 3
#    HAS BUSINESS RESPONSE: False
#    WHY CORRECT: Very short review with minimal content
# ------------------------------------------------------------
#
# 8. CORRECT EXAMPLE:
#    TEXT: Helps
#    BUSINESS CATEGORY: Employment search service
#    RATING: 4
#    HAS BUSINESS RESPONSE: False
#    WHY CORRECT: Very short review with minimal content
# ------------------------------------------------------------
#
# 9. CORRECT EXAMPLE:
#    TEXT: ❣️
#    BUSINESS CATEGORY: Fast food restaurant, Breakfast restaurant, Chicken restaurant, Hamburger restaurant
#    RATING: 5
#    HAS BUSINESS RESPONSE: True
#    WHY CORRECT: Very short review with minimal content
# ------------------------------------------------------------
#
# 10. CORRECT EXAMPLE:
#    TEXT: Enjoy
#    BUSINESS CATEGORY: Shopping mall
#    RATING: 5
#    HAS BUSINESS RESPONSE: False
#    WHY CORRECT: Very short review with minimal content
# ------------------------------------------------------------
#
# --- MISLABELED EXAMPLES ---
#
# 1. MISLABELED EXAMPLE:
#    TEXT: Bring your appetite. Best tortas in town.
#    BUSINESS CATEGORY: Mexican restaurant, Breakfast restaurant, Burrito restaurant, Restaurant, Sandwich shop
#    RATING: 5
#    HAS BUSINESS RESPONSE: False
#    CURRENT LABEL: Low quality review
#    SUGGESTED LABEL: Acceptable review
#    WHY MISLABELED: Legitimate review about business experience
# ------------------------------------------------------------
#
# 2. MISLABELED EXAMPLE:
#    TEXT: Good inexpensive Mexican food.
#    BUSINESS CATEGORY: Mexican restaurant, Restaurant
#    RATING: 5
#    HAS BUSINESS RESPONSE: True
#    CURRENT LABEL: Low quality review
#    SUGGESTED LABEL: Acceptable review
#    WHY MISLABELED: Legitimate review about business experience
# ------------------------------------------------------------
#
# 3. MISLABELED EXAMPLE:
#    TEXT: Love this place. Amazing drinks. Fantastic food!!
#    BUSINESS CATEGORY: Mexican restaurant, Restaurant
#    RATING: 5
#    HAS BUSINESS RESPONSE: True
#    CURRENT LABEL: Low quality review
#    SUGGESTED LABEL: Acceptable review
#    WHY MISLABELED: Legitimate review about business experience
# ------------------------------------------------------------
#
# 4. MISLABELED EXAMPLE:
#    TEXT: Food was amazing definitely coming back for the drive just for my birthday! You don't know what good ribs and a good burger is untill you tasted the ones here.
#    BUSINESS CATEGORY: Barbecue restaurant, Bar, Restaurant, Steak house
#    RATING: 5
#    HAS BUSINESS RESPONSE: False
#    CURRENT LABEL: Low quality review
#    SUGGESTED LABEL: Acceptable review
#    WHY MISLABELED: Legitimate review about business experience
# ------------------------------------------------------------
#
# 5. MISLABELED EXAMPLE:
#    TEXT: Great service
#    BUSINESS CATEGORY: Smog inspection station
#    RATING: 4
#    HAS BUSINESS RESPONSE: False
#    CURRENT LABEL: Low quality review
#    SUGGESTED LABEL: Acceptable review
#    WHY MISLABELED: Legitimate review about business experience
# ------------------------------------------------------------
#
# 6. MISLABELED EXAMPLE:
#    TEXT: Authentic street tacos! A bit pricey but they load it up ;) and their salsa bar is always fresh!
#    BUSINESS CATEGORY: Mexican restaurant, Restaurant, Taco restaurant
#    RATING: 5
#    HAS BUSINESS RESPONSE: False
#    CURRENT LABEL: Low quality review
#    SUGGESTED LABEL: Acceptable review
#    WHY MISLABELED: Legitimate review about business experience
# ------------------------------------------------------------
#
# 7. MISLABELED EXAMPLE:
#    TEXT: Loved this store! Heard an interview on NPR with the owner of this store and took off the next day and drove the 26 miles to get to it. Did not know what half of what I saw was, but it sure made me want to learn how to use it. Food from every country in the Middle East. Great, friendly service, made me feel like I was in an open market in some exotic Arab country!  I'll be back!!
#    BUSINESS CATEGORY: Grocery store, European institution, Gourmet grocery store, Health food store, Indian grocery store, Italian grocery store, Kosher grocery store, Natural goods store, Russian grocery store, Wholesale grocer
#    RATING: 5
#    HAS BUSINESS RESPONSE: False
#    CURRENT LABEL: Low quality review
#    SUGGESTED LABEL: Acceptable review
#    WHY MISLABELED: Legitimate review about business experience
# ------------------------------------------------------------
#
# 8. MISLABELED EXAMPLE:
#    TEXT: Great selection.  It's also family owned.
#    BUSINESS CATEGORY: Pet supply store, Pet friendly accommodation, Pet store
#    RATING: 5
#    HAS BUSINESS RESPONSE: True
#    CURRENT LABEL: Low quality review
#    SUGGESTED LABEL: Acceptable review
#    WHY MISLABELED: Legitimate review about business experience
# ------------------------------------------------------------
#
# 9. MISLABELED EXAMPLE:
#    TEXT: Easy parking
#    BUSINESS CATEGORY: Outlet mall
#    RATING: 5
#    HAS BUSINESS RESPONSE: False
#    CURRENT LABEL: Low quality review
#    SUGGESTED LABEL: Acceptable review
#    WHY MISLABELED: Legitimate review about business experience
# ------------------------------------------------------------
#
# 10. MISLABELED EXAMPLE:
#    TEXT: Friendly, lots of equipment to work on.
#    BUSINESS CATEGORY: Gym, Fitness center, Personal trainer, Spa and health club, Tanning salon
#    RATING: 5
#    HAS BUSINESS RESPONSE: False
#    CURRENT LABEL: Low quality review
#    SUGGESTED LABEL: Acceptable review
#    WHY MISLABELED: Legitimate review about business experience
# ------------------------------------------------------------
#
# ============================================================
# ANALYZING: RANT WITHOUT VISIT
# ============================================================
# Total samples in category: 867
# CATEGORY SUMMARY:
# Total samples in dataset: 867
# Analyzed sample: 867
# Correct labels: 0/867 (0.0%)
# Mislabeled: 867/867 (100.0%)
#
# --- CORRECTLY LABELED EXAMPLES ---
#
# --- MISLABELED EXAMPLES ---
#
# 1. MISLABELED EXAMPLE:
#    TEXT: The food is OK. Definitely budget friendly
#    BUSINESS CATEGORY: Pizza restaurant, Delivery service, Takeout Restaurant
#    RATING: 3
#    HAS BUSINESS RESPONSE: True
#    CURRENT LABEL: Rant without visit
#    SUGGESTED LABEL: Acceptable review
#    WHY MISLABELED: Legitimate review about business experience
# ------------------------------------------------------------
#
# 2. MISLABELED EXAMPLE:
#    TEXT: I love this place, pretty much outfitted my entire office and my house. Quality is decent but Affordable.
#    BUSINESS CATEGORY: Furniture store, Bedroom furniture store, Mattress store, Office furniture store, Outdoor furniture store, Shelving store
#    RATING: 5
#    HAS BUSINESS RESPONSE: False
#    CURRENT LABEL: Rant without visit
#    SUGGESTED LABEL: Acceptable review
#    WHY MISLABELED: Legitimate review about business experience
# ------------------------------------------------------------
#
# 3. MISLABELED EXAMPLE:
#    TEXT: Seemed to have staff/training/QA problems.
#    BUSINESS CATEGORY: Restaurant, Fast food restaurant
#    RATING: 3
#    HAS BUSINESS RESPONSE: False
#    CURRENT LABEL: Rant without visit
#    SUGGESTED LABEL: Acceptable review
#    WHY MISLABELED: Legitimate review about business experience
# ------------------------------------------------------------
#
# 4. MISLABELED EXAMPLE:
#    TEXT: Poor extremely poor customer service and bad mechanics...unacceptable business...bought a vehicle it had problems from the beginning n I thank God we took pics b4 we drove off the property...mechanic said we did something wrong but pics don't lie!!! I would take my 1 star rating back if I could...customers BEWARE! I do not recommend them at all...
#    BUSINESS CATEGORY: Used car dealer, Repair service
#    RATING: 1
#    HAS BUSINESS RESPONSE: False
#    CURRENT LABEL: Rant without visit
#    SUGGESTED LABEL: Acceptable review
#    WHY MISLABELED: Legitimate review about business experience
# ------------------------------------------------------------
#
# 5. MISLABELED EXAMPLE:
#    TEXT: Very nice folks at the gate, mostly, but when returning to the lake after being already registered, and having to wait in the registration line again, just seems dumb and inefficient.  Otherwise a great experience. Rangers driving around are friendly and helpful.
#    BUSINESS CATEGORY: Park, Tourist attraction
#    RATING: 4
#    HAS BUSINESS RESPONSE: False
#    CURRENT LABEL: Rant without visit
#    SUGGESTED LABEL: Acceptable review
#    WHY MISLABELED: Legitimate review about business experience
# ------------------------------------------------------------
#
# 6. MISLABELED EXAMPLE:
#    TEXT: I took my friend there for the first time and we both loved it. We split a chocolate malt too.
#    BUSINESS CATEGORY: Ice cream shop, American restaurant, Dessert shop
#    RATING: 5
#    HAS BUSINESS RESPONSE: False
#    CURRENT LABEL: Rant without visit
#    SUGGESTED LABEL: Acceptable review
#    WHY MISLABELED: Legitimate review about business experience
# ------------------------------------------------------------
#
# 7. MISLABELED EXAMPLE:
#    TEXT: Worst pad Thai ever
#    BUSINESS CATEGORY: Japanese restaurant, Asian fusion restaurant, Sushi restaurant
#    RATING: 1
#    HAS BUSINESS RESPONSE: False
#    CURRENT LABEL: Rant without visit
#    SUGGESTED LABEL: Acceptable review
#    WHY MISLABELED: Legitimate review about business experience
# ------------------------------------------------------------
#
# 8. MISLABELED EXAMPLE:
#    TEXT: They care about pets and they deliver
#    BUSINESS CATEGORY: Veterinary pharmacy
#    RATING: 5
#    HAS BUSINESS RESPONSE: True
#    CURRENT LABEL: Rant without visit
#    SUGGESTED LABEL: Acceptable review
#    WHY MISLABELED: Legitimate review about business experience
# ------------------------------------------------------------
#
# 9. MISLABELED EXAMPLE:
#    TEXT: Nice water park. Over priced real food. Not all slides in good/working condition. Wave pool is a favorite especially with rafts.
#    BUSINESS CATEGORY: Water park, Amusement center, Tourist attraction
#    RATING: 3
#    HAS BUSINESS RESPONSE: False
#    CURRENT LABEL: Rant without visit
#    SUGGESTED LABEL: Acceptable review
#    WHY MISLABELED: Legitimate review about business experience
# ------------------------------------------------------------
#
# 10. MISLABELED EXAMPLE:
#    TEXT: Always find something interesting here. I like the canned Thai Tea
#    BUSINESS CATEGORY: Asian grocery store, Grocery store, Indian grocery store, Japanese grocery store, Korean grocery store, Produce market, Seafood market, Supermarket
#    RATING: 5
#    HAS BUSINESS RESPONSE: False
#    CURRENT LABEL: Rant without visit
#    SUGGESTED LABEL: Acceptable review
#    WHY MISLABELED: Legitimate review about business experience
# ------------------------------------------------------------
#
# ============================================================
# ANALYZING: IRRELEVANT CONTENT
# ============================================================
# Total samples in category: 151
# CATEGORY SUMMARY:
# Total samples in dataset: 151
# Analyzed sample: 151
# Correct labels: 0/151 (0.0%)
# Mislabeled: 151/151 (100.0%)
#
# --- CORRECTLY LABELED EXAMPLES ---
#
# --- MISLABELED EXAMPLES ---
#
# 1. MISLABELED EXAMPLE:
#    TEXT: Great shopping selection and quick check out at Ross's.
#    BUSINESS CATEGORY: Shopping mall
#    RATING: 5
#    HAS BUSINESS RESPONSE: False
#    CURRENT LABEL: Irrelevant content
#    SUGGESTED LABEL: Acceptable review
#    WHY MISLABELED: Legitimate review about business experience
# ------------------------------------------------------------
#
# 2. MISLABELED EXAMPLE:
#    TEXT: Not too busy of a gas station so that’s nice. I don’t like the credit card machines that hold onto your card for several minutes. Took a bunch of times to get mine out at first. Trick is to push it back in more then pull out.
#    BUSINESS CATEGORY: Gas station
#    RATING: 4
#    HAS BUSINESS RESPONSE: False
#    CURRENT LABEL: Irrelevant content
#    SUGGESTED LABEL: Acceptable review
#    WHY MISLABELED: Legitimate review about business experience
# ------------------------------------------------------------
#
# 3. MISLABELED EXAMPLE:
#    TEXT: Angry Crab Shack is a nice place to dine .Their shrimp tri-fecta sauce goes so well with the Shrimp 🍤 👍
#    BUSINESS CATEGORY: Crab house, Barbecue restaurant, Cajun restaurant, Seafood restaurant
#    RATING: 4
#    HAS BUSINESS RESPONSE: False
#    CURRENT LABEL: Irrelevant content
#    SUGGESTED LABEL: Acceptable review
#    WHY MISLABELED: Legitimate review about business experience
# ------------------------------------------------------------
#
# 4. MISLABELED EXAMPLE:
#    TEXT: Must see place when you are in the area.
#    BUSINESS CATEGORY: Hotel
#    RATING: 5
#    HAS BUSINESS RESPONSE: False
#    CURRENT LABEL: Irrelevant content
#    SUGGESTED LABEL: Acceptable review
#    WHY MISLABELED: Legitimate review about business experience
# ------------------------------------------------------------
#
# 5. MISLABELED EXAMPLE:
#    TEXT: Great car wash. $7 for everything but no blow dry. I use this car wash all the time.
#    BUSINESS CATEGORY: Car wash
#    RATING: 5
#    HAS BUSINESS RESPONSE: False
#    CURRENT LABEL: Irrelevant content
#    SUGGESTED LABEL: Acceptable review
#    WHY MISLABELED: Legitimate review about business experience
# ------------------------------------------------------------
#
# 6. MISLABELED EXAMPLE:
#    TEXT: Love the Sketcher's store
#    BUSINESS CATEGORY: Shopping mall
#    RATING: 5
#    HAS BUSINESS RESPONSE: False
#    CURRENT LABEL: Irrelevant content
#    SUGGESTED LABEL: Acceptable review
#    WHY MISLABELED: Legitimate review about business experience
# ------------------------------------------------------------
#
# 7. MISLABELED EXAMPLE:
#    TEXT: Okay greasy tho
#    BUSINESS CATEGORY: Diner, American restaurant, Breakfast restaurant
#    RATING: 3
#    HAS BUSINESS RESPONSE: False
#    CURRENT LABEL: Irrelevant content
#    SUGGESTED LABEL: Acceptable review
#    WHY MISLABELED: Legitimate review about business experience
# ------------------------------------------------------------
#
# 8. MISLABELED EXAMPLE:
#    TEXT: Good food. Very reasonable prices. Clean and fast service. Fajitas for two, guacamole and fried ice cream.
#    BUSINESS CATEGORY: Restaurant
#    RATING: 5
#    HAS BUSINESS RESPONSE: False
#    CURRENT LABEL: Irrelevant content
#    SUGGESTED LABEL: Acceptable review
#    WHY MISLABELED: Legitimate review about business experience
# ------------------------------------------------------------
#
# 9. MISLABELED EXAMPLE:
#    TEXT: The food is very good and they have a great variety on drinks.
#    BUSINESS CATEGORY: Mexican restaurant
#    RATING: 5
#    HAS BUSINESS RESPONSE: False
#    CURRENT LABEL: Irrelevant content
#    SUGGESTED LABEL: Acceptable review
#    WHY MISLABELED: Legitimate review about business experience
# ------------------------------------------------------------
#
# 10. MISLABELED EXAMPLE:
#    TEXT: meh
#    BUSINESS CATEGORY: Corporate office
#    RATING: 2
#    HAS BUSINESS RESPONSE: False
#    CURRENT LABEL: Irrelevant content
#    SUGGESTED LABEL: Low quality review
#    WHY MISLABELED: Very short review with minimal content
# ------------------------------------------------------------
#
# ============================================================
# ANALYZING: ADVERTISEMENT
# ============================================================
# Total samples in category: 27
# CATEGORY SUMMARY:
# Total samples in dataset: 27
# Analyzed sample: 27
# Correct labels: 0/27 (0.0%)
# Mislabeled: 27/27 (100.0%)
#
# --- CORRECTLY LABELED EXAMPLES ---
#
# --- MISLABELED EXAMPLES ---
#
# 1. MISLABELED EXAMPLE:
#    TEXT: Covid 19 deal here. Most amenities were closed, but such a beautiful and relaxing place. Beds are amazingly comfortable.
#    BUSINESS CATEGORY: Hotel
#    RATING: 5
#    HAS BUSINESS RESPONSE: False
#    CURRENT LABEL: Advertisement
#    SUGGESTED LABEL: Acceptable review
#    WHY MISLABELED: Legitimate review about business experience
# ------------------------------------------------------------
#
# 2. MISLABELED EXAMPLE:
#    TEXT: They did a great job replacing my windshield in my mustang but they advertise 1 they'll come to you when you're working and nope I had to make arrangements to get my car there, back home after that was such a stressful day since I was working 11 hr shift so I was trying to work around that too. Then for #2 they also advertise they install backup cameras so when I asked a guy about it he said no he's short handed but he can sell me 1 then laughed a little. I told him I don't need if I want I have to and I just need to get them in my truck my truck in car so I asked about other people who could be possibly put these in my car and I got a tinting place yeah they run more than tint which I had them fix my driver's widow and it was junk so why would I let them do my cameras. Um no thanks
#    BUSINESS CATEGORY: Auto glass shop, Car stereo store, Glass shop, Truck accessories store, Window tinting service
#    RATING: 4
#    HAS BUSINESS RESPONSE: False
#    CURRENT LABEL: Advertisement
#    SUGGESTED LABEL: Acceptable review
#    WHY MISLABELED: Legitimate review about business experience
# ------------------------------------------------------------
#
# 3. MISLABELED EXAMPLE:
#    TEXT: Worth the eait.
#    BUSINESS CATEGORY: Italian restaurant, Family restaurant, Pizza restaurant
#    RATING: 5
#    HAS BUSINESS RESPONSE: True
#    CURRENT LABEL: Advertisement
#    SUGGESTED LABEL: Acceptable review
#    WHY MISLABELED: Legitimate review about business experience
# ------------------------------------------------------------
#
# 4. MISLABELED EXAMPLE:
#    TEXT: Service and food are always great. There's a blonde lady with glasses that does a fantastic job.
#    BUSINESS CATEGORY: Buffet restaurant, Caterer, Family restaurant, Health food restaurant, Takeout Restaurant, Salad shop, Soup restaurant, Vegan restaurant, Vegetarian restaurant
#    RATING: 5
#    HAS BUSINESS RESPONSE: False
#    CURRENT LABEL: Advertisement
#    SUGGESTED LABEL: Acceptable review
#    WHY MISLABELED: Legitimate review about business experience
# ------------------------------------------------------------
#
# 5. MISLABELED EXAMPLE:
#    TEXT: Fresh sandwiches made to order. Healthier than most fast food, and tasty!
#    BUSINESS CATEGORY: Sandwich shop, Bakery, Deli, Dessert shop, Family restaurant, Fast food restaurant, Pizza restaurant, Restaurant, Soup restaurant
#    RATING: 4
#    HAS BUSINESS RESPONSE: False
#    CURRENT LABEL: Advertisement
#    SUGGESTED LABEL: Acceptable review
#    WHY MISLABELED: Legitimate review about business experience
# ------------------------------------------------------------
#
# 6. MISLABELED EXAMPLE:
#    TEXT: Both my Husband and I have service dogs and we have never had problems here.
#    BUSINESS CATEGORY: Movie theater
#    RATING: 5
#    HAS BUSINESS RESPONSE: False
#    CURRENT LABEL: Advertisement
#    SUGGESTED LABEL: Acceptable review
#    WHY MISLABELED: Legitimate review about business experience
# ------------------------------------------------------------
#
# 7. MISLABELED EXAMPLE:
#    TEXT: Home project supplys furnished here.
#    BUSINESS CATEGORY: Home improvement store, Appliance store, Bathroom supply store, Cabinet store, Hardware store, Lighting store, Paint store, Rug store, Tool store, Window treatment store
#    RATING: 4
#    HAS BUSINESS RESPONSE: False
#    CURRENT LABEL: Advertisement
#    SUGGESTED LABEL: Acceptable review
#    WHY MISLABELED: Legitimate review about business experience
# ------------------------------------------------------------
#
# 8. MISLABELED EXAMPLE:
#    TEXT: Love the family,  love the food
#    BUSINESS CATEGORY: Mexican restaurant
#    RATING: 5
#    HAS BUSINESS RESPONSE: False
#    CURRENT LABEL: Advertisement
#    SUGGESTED LABEL: Acceptable review
#    WHY MISLABELED: Legitimate review about business experience
# ------------------------------------------------------------
#
# 9. MISLABELED EXAMPLE:
#    TEXT: Cuts
#    BUSINESS CATEGORY: Clothing store, Department store, Men's clothing store, Shoe store, Women's clothing store
#    RATING: 5
#    HAS BUSINESS RESPONSE: False
#    CURRENT LABEL: Advertisement
#    SUGGESTED LABEL: Low quality review
#    WHY MISLABELED: Very short review with minimal content
# ------------------------------------------------------------
#
# 10. MISLABELED EXAMPLE:
#    TEXT: Good fresh food will be back
#    BUSINESS CATEGORY: Italian restaurant, Pizza delivery, Pizza restaurant
#    RATING: 5
#    HAS BUSINESS RESPONSE: False
#    CURRENT LABEL: Advertisement
#    SUGGESTED LABEL: Acceptable review
#    WHY MISLABELED: Legitimate review about business experience
# ------------------------------------------------------------
#
# ================================================================================
# CONSOLIDATED PROMPTING IMPROVEMENT STRATEGY
# ================================================================================
#
# ACCURACY SUMMARY BY CATEGORY:
# Acceptable review        :  98.4% accurate
# Low quality review       :   1.6% accurate
# Rant without visit       :   0.0% accurate
# Irrelevant content       :   0.0% accurate
# Advertisement            :   0.0% accurate
#
# MAJOR ISSUES IDENTIFIED:
#
# Low quality review:
#   Problem: Flagging legitimate detailed reviews as low quality
#   Fix: Only flag extremely short reviews (under 10 characters)
#   Fix: Don't flag reviews with specific experiences as low quality
#   Fix: Focus on meaningless reviews like single words
#
# Rant without visit:
#   Problem: Flagging reviews with clear visit evidence as non-visitor rants
#   Fix: Look for explicit 'never been here' language
#   Fix: Reviews mentioning staff interaction show visits
#   Fix: Detailed service descriptions indicate actual experience
#   Fix: Use business responses that deny customer relationship as strong evidence
#
# Irrelevant content:
#   Problem: Flagging relevant content as irrelevant
#   Fix: Food/kitchen/service content IS relevant to restaurants
#   Fix: Only flag if review explicitly discusses unrelated topics
#   Fix: Context matters - enthusiastic food reviews are relevant
#
# Advertisement:
#   Problem: Confusing customer recommendations with advertisements
#   Fix: Only flag reviews with actual URLs, promo codes, or phone numbers
#   Fix: Don't flag positive customer experiences as ads
#   Fix: Look for business self-promotion, not customer enthusiasm
#
# CORRECTED PROMPT STRATEGY:
#
# TASK: Classify this review for policy violations using STRICT criteria.
#
# CONTEXT:
# Business: [Business Name]
# Category: [Business Category]
# Rating: [1-5 stars]
# Review: "[Review Text]"
# Business Response: "[If available]"
#
# STRICT CLASSIFICATION RULES:
#
# 1. ADVERTISEMENT - Only if contains:
#    - Actual website URLs (www.site.com, http://)
#    - Specific promo codes ("use code SAVE20")
#    - Phone numbers with "call us at"
#    - Direct business promotion language
#    NOT customer enthusiasm or recommendations
#
# 2. IRRELEVANT CONTENT - Only if review explicitly discusses:
#    - Topics completely unrelated to business type
#    - Wrong business entirely
#    - Personal matters unrelated to the service
#    NOT food reviews for restaurants or service reviews for services
#
# 3. RANT WITHOUT VISIT - Only if explicitly states OR business confirms:
#    - "Never been here but..."
#    - "Haven't visited but heard..."
#    - "Based on what others told me..."
#    - Business responds "never been a customer" or similar
#    NOT detailed negative experiences (these show actual visits)
#
# 4. ACCEPTABLE REVIEW - Default for legitimate customer experiences:
#    - Any review discussing actual business experience
#    - Positive, negative, or neutral customer feedback
#    - Reviews matching business category appropriately
#
# DEFAULT: When in doubt, classify as ACCEPTABLE REVIEW
# Most customer reviews should be acceptable unless clear violations exist.
#
# ANSWER: [Category]
# REASONING: [Why this specific classification]
#
#
# Validation complete. The specific example demonstrates how business responses can confirm 'Rant without visit' violations.

# %% [markdown]
# # got to improve

# %%
def display_examples_by_suggested_label(df, max_examples_per_category=10):
    """Find and display examples for each suggested label category"""
    
    print("\n" + "="*80)
    print("EXAMPLES BY SUGGESTED LABEL CATEGORIES")
    print("="*80)
    
    # Target categories to find examples for
    target_categories = [
        'Acceptable review',
        'Low quality review', 
        'Rant without visit',
        'Irrelevant content',
        'Advertisement'
    ]
    
    # Store examples for each category
    examples_by_category = {category: [] for category in target_categories}
    
    print("Analyzing entire dataset to find examples for each suggested category...")
    
    # Analyze all reviews to get suggested labels
    for idx, row in df.iterrows():
        text = str(row['text'])
        business_category = str(row.get('category_str', 'Unknown'))
        rating = row.get('rating', 'N/A')
        has_response = str(row.get('resp', '')).strip() not in ['', 'nan', 'None']
        resp_text = row.get('resp', '')
        current_label = row.get('classification', 'Unknown')
        
        # Get suggested label
        analysis = analyze_single_review(text, current_label, business_category, rating, has_response, resp_text)
        suggested_label = analysis['suggested_label']
        
        # Store example if it matches our target categories and we need more examples
        if suggested_label in target_categories and len(examples_by_category[suggested_label]) < max_examples_per_category:
            examples_by_category[suggested_label].append({
                'text': text,
                'current_label': current_label,
                'business_category': business_category,
                'rating': rating,
                'has_response': has_response,
                'confidence': analysis['confidence'],
                'reason': analysis['reason']
            })
        
        # Check if we have enough examples for all categories
        if all(len(examples) >= max_examples_per_category for examples in examples_by_category.values()):
            break
    
    # Display examples for each category
    for category in target_categories:
        examples = examples_by_category[category]
        print(f"\n{'='*60}")
        print(f"SUGGESTED LABEL: {category.upper()}")
        print(f"{'='*60}")
        print(f"Found {len(examples)} examples")
        
        if not examples:
            print("No examples found for this category")
            continue
            
        for i, example in enumerate(examples, 1):
            print(f"\n{i}. EXAMPLE:")
            print(f"   TEXT: {example['text']}")
            print(f"   BUSINESS CATEGORY: {example['business_category']}")
            print(f"   RATING: {example['rating']}")
            print(f"   CURRENT LABEL: {example['current_label']}")
            print(f"   HAS BUSINESS RESPONSE: {example['has_response']}")
            print(f"   CONFIDENCE: {example['confidence']}")
            print(f"   REASONING: {example['reason']}")
            print("-" * 60)
    
    # Summary statistics
    print(f"\n{'='*60}")
    print("SUMMARY OF SUGGESTED LABELS")
    print(f"{'='*60}")
    
    for category in target_categories:
        count = len(examples_by_category[category])
        print(f"{category:25}: {count:3d} examples found")
    
    total_examples = sum(len(examples) for examples in examples_by_category.values())
    print(f"{'Total examples':25}: {total_examples:3d}")

# Run the example display function
if __name__ == "__main__":
    # Add this after the main validation code
    display_examples_by_suggested_label(df, max_examples_per_category=10)
# Out:
# ================================================================================
# EXAMPLES BY SUGGESTED LABEL CATEGORIES
# ================================================================================
# Analyzing entire dataset to find examples for each suggested category...
#
# ============================================================
# SUGGESTED LABEL: ACCEPTABLE REVIEW
# ============================================================
# Found 10 examples
#
# 1. EXAMPLE:
#    TEXT: Great people. A one stop store for anything you might need.
#    BUSINESS CATEGORY: Grocery store, Propane supplier
#    RATING: 5
#    CURRENT LABEL: Acceptable review
#    HAS BUSINESS RESPONSE: False
#    CONFIDENCE: Medium
#    REASONING: Legitimate review about business experience
# ------------------------------------------------------------
#
# 2. EXAMPLE:
#    TEXT: Always spend too much!
#    BUSINESS CATEGORY: Warehouse store, Department store
#    RATING: 5
#    CURRENT LABEL: Acceptable review
#    HAS BUSINESS RESPONSE: False
#    CONFIDENCE: Medium
#    REASONING: Legitimate review about business experience
# ------------------------------------------------------------
#
# 3. EXAMPLE:
#    TEXT: Bring your appetite. Best tortas in town.
#    BUSINESS CATEGORY: Mexican restaurant, Breakfast restaurant, Burrito restaurant, Restaurant, Sandwich shop
#    RATING: 5
#    CURRENT LABEL: Low quality review
#    HAS BUSINESS RESPONSE: False
#    CONFIDENCE: Medium
#    REASONING: Legitimate review about business experience
# ------------------------------------------------------------
#
# 4. EXAMPLE:
#    TEXT: I like shopping here
#    BUSINESS CATEGORY: Sporting goods store, Boat dealer, Camping store, Gun shop
#    RATING: 5
#    CURRENT LABEL: Acceptable review
#    HAS BUSINESS RESPONSE: False
#    CONFIDENCE: Medium
#    REASONING: Legitimate review about business experience
# ------------------------------------------------------------
#
# 5. EXAMPLE:
#    TEXT: Fine if you want to browse for video games. They pay very little for used hardware/games and they charge a lot for used hardware/games.
#    BUSINESS CATEGORY: Video game store, Cell phone store, Collectibles store, Electronics store
#    RATING: 3
#    CURRENT LABEL: Acceptable review
#    HAS BUSINESS RESPONSE: False
#    CONFIDENCE: Medium
#    REASONING: Legitimate review about business experience
# ------------------------------------------------------------
#
# 6. EXAMPLE:
#    TEXT: Sushi was amazing, very fair prices as well.  Who doesn't love revolving sushi.
#    BUSINESS CATEGORY: Sushi restaurant
#    RATING: 5
#    CURRENT LABEL: Acceptable review
#    HAS BUSINESS RESPONSE: False
#    CONFIDENCE: Medium
#    REASONING: Legitimate review about business experience
# ------------------------------------------------------------
#
# 7. EXAMPLE:
#    TEXT: Good inexpensive Mexican food.
#    BUSINESS CATEGORY: Mexican restaurant, Restaurant
#    RATING: 5
#    CURRENT LABEL: Low quality review
#    HAS BUSINESS RESPONSE: True
#    CONFIDENCE: Medium
#    REASONING: Legitimate review about business experience
# ------------------------------------------------------------
#
# 8. EXAMPLE:
#    TEXT: Kohl's is right behind IHOP so I get a great meal and shopping too
#    BUSINESS CATEGORY: Restaurant, American restaurant, Breakfast restaurant, Family restaurant
#    RATING: 5
#    CURRENT LABEL: Acceptable review
#    HAS BUSINESS RESPONSE: False
#    CONFIDENCE: Medium
#    REASONING: Legitimate review about business experience
# ------------------------------------------------------------
#
# 9. EXAMPLE:
#    TEXT: Fishy, greasy, not real fresh food, then short Asian guy, with glasses said:"You are only giving me $2, for a tip, there are two of you". Thisvis a self serve buffet, a small tip is enough. All the kid did was ask us what soft drink we wanted
#    BUSINESS CATEGORY: Japanese restaurant, Asian restaurant, Bar, Bar & grill, Buffet restaurant, Chinese restaurant
#    RATING: 1
#    CURRENT LABEL: Acceptable review
#    HAS BUSINESS RESPONSE: False
#    CONFIDENCE: Medium
#    REASONING: Legitimate review about business experience
# ------------------------------------------------------------
#
# 10. EXAMPLE:
#    TEXT: Love this place
#    BUSINESS CATEGORY: Food bank, Non-profit organization
#    RATING: 5
#    CURRENT LABEL: Acceptable review
#    HAS BUSINESS RESPONSE: False
#    CONFIDENCE: Medium
#    REASONING: Legitimate review about business experience
# ------------------------------------------------------------
#
# ============================================================
# SUGGESTED LABEL: LOW QUALITY REVIEW
# ============================================================
# Found 10 examples
#
# 1. EXAMPLE:
#    TEXT: Darts
#    BUSINESS CATEGORY: Bar
#    RATING: 5
#    CURRENT LABEL: Acceptable review
#    HAS BUSINESS RESPONSE: True
#    CONFIDENCE: Low
#    REASONING: Very short review with minimal content
# ------------------------------------------------------------
#
# 2. EXAMPLE:
#    TEXT: Nice
#    BUSINESS CATEGORY: Massage therapist, Holistic medicine practitioner, Massage spa
#    RATING: 5
#    CURRENT LABEL: Low quality review
#    HAS BUSINESS RESPONSE: True
#    CONFIDENCE: Low
#    REASONING: Very short review with minimal content
# ------------------------------------------------------------
#
# 3. EXAMPLE:
#    TEXT: Cool
#    BUSINESS CATEGORY: Supermarket, Bakery, Butcher shop, Deli, Grocery store, Produce market
#    RATING: 5
#    CURRENT LABEL: Acceptable review
#    HAS BUSINESS RESPONSE: False
#    CONFIDENCE: Low
#    REASONING: Very short review with minimal content
# ------------------------------------------------------------
#
# 4. EXAMPLE:
#    TEXT: Nice
#    BUSINESS CATEGORY: Pizza restaurant, Delivery Restaurant
#    RATING: 5
#    CURRENT LABEL: Acceptable review
#    HAS BUSINESS RESPONSE: False
#    CONFIDENCE: Low
#    REASONING: Very short review with minimal content
# ------------------------------------------------------------
#
# 5. EXAMPLE:
#    TEXT: Great
#    BUSINESS CATEGORY: Laundromat
#    RATING: 5
#    CURRENT LABEL: Acceptable review
#    HAS BUSINESS RESPONSE: True
#    CONFIDENCE: Low
#    REASONING: Very short review with minimal content
# ------------------------------------------------------------
#
# 6. EXAMPLE:
#    TEXT: Fun
#    BUSINESS CATEGORY: Bar
#    RATING: 4
#    CURRENT LABEL: Rant without visit
#    HAS BUSINESS RESPONSE: False
#    CONFIDENCE: Low
#    REASONING: Very short review with minimal content
# ------------------------------------------------------------
#
# 7. EXAMPLE:
#    TEXT: A-ok
#    BUSINESS CATEGORY: Italian restaurant
#    RATING: 4
#    CURRENT LABEL: Acceptable review
#    HAS BUSINESS RESPONSE: False
#    CONFIDENCE: Low
#    REASONING: Very short review with minimal content
# ------------------------------------------------------------
#
# 8. EXAMPLE:
#    TEXT: Ok
#    BUSINESS CATEGORY: Chicken restaurant, Cajun restaurant, Fast food restaurant, Restaurant, Seafood restaurant
#    RATING: 4
#    CURRENT LABEL: Rant without visit
#    HAS BUSINESS RESPONSE: False
#    CONFIDENCE: Low
#    REASONING: Very short review with minimal content
# ------------------------------------------------------------
#
# 9. EXAMPLE:
#    TEXT: Love
#    BUSINESS CATEGORY: Seafood restaurant, Fast food restaurant, Fish & chips restaurant, Restaurant
#    RATING: 5
#    CURRENT LABEL: Acceptable review
#    HAS BUSINESS RESPONSE: False
#    CONFIDENCE: Low
#    REASONING: Very short review with minimal content
# ------------------------------------------------------------
#
# 10. EXAMPLE:
#    TEXT: 👍
#    BUSINESS CATEGORY: Casino, Tourist attraction
#    RATING: 4
#    CURRENT LABEL: Acceptable review
#    HAS BUSINESS RESPONSE: False
#    CONFIDENCE: Low
#    REASONING: Very short review with minimal content
# ------------------------------------------------------------
#
# ============================================================
# SUGGESTED LABEL: RANT WITHOUT VISIT
# ============================================================
# Found 2 examples
#
# 1. EXAMPLE:
#    TEXT: All I can say is SMH about this place be careful
#    BUSINESS CATEGORY: Transmission shop, Auto machine shop, Auto repair shop, Auto tune up service, Brake shop, Car repair and maintenance, Engine rebuilding service, Mechanic, Small engine repair service
#    RATING: 1
#    CURRENT LABEL: Acceptable review
#    HAS BUSINESS RESPONSE: True
#    CONFIDENCE: High
#    REASONING: Business confirms no customer relationship
# ------------------------------------------------------------
#
# 2. EXAMPLE:
#    TEXT: This Ace is not the helpful hardware store. I went in looking for a plumbing part. I asked sales associate Jeff if he knew if they sold the part. He said it if it's not on the shelf then we don't sell it. Since I just walked into your store and have never been here before I really don't know what's on your shelves and would appreciate a sales associate helping me find what I need. UPDATE 02/25/2021 customers have to wear mask s but the employees do not have to. Went into the store today with my mask on as required per entry rules. But the employee and the hardware department was not wearing his mask?
#    BUSINESS CATEGORY: Hardware store, Home improvement store, Paint store, Tool store
#    RATING: 1
#    CURRENT LABEL: Low quality review
#    HAS BUSINESS RESPONSE: True
#    CONFIDENCE: Medium
#    REASONING: Appears to complain without visiting
# ------------------------------------------------------------
#
# ============================================================
# SUGGESTED LABEL: IRRELEVANT CONTENT
# ============================================================
# Found 5 examples
#
# 1. EXAMPLE:
#    TEXT: I usually love Texas Roadhouse's grilled salmon and get it at different locations while traveling. The fish is usually nicely salted and seasoned,has mild fish taste and flakes apart easily. This location gave me overcooked fish that lacked salt and seasoning and had a strong unpleasant fishy flavor. It tasted like someone took old raw fish, cooked it with no seasoning and served it. I paid $17 for side dishes so I'm not happy. The fish went into the garbage and I will never eat at this location again.
#    BUSINESS CATEGORY: Steak house, American restaurant, New American restaurant
#    RATING: 1
#    CURRENT LABEL: Acceptable review
#    HAS BUSINESS RESPONSE: True
#    CONFIDENCE: High
#    REASONING: Content not related to business type (Steak house, American restaurant, New American restaurant)
# ------------------------------------------------------------
#
# 2. EXAMPLE:
#    TEXT: Well what can I say....terrible experience. Started with us waiting at table for 7 min before being acknowledged by server. Then another 6 before drinks were brought an ice tea and a water! We both ordered hamburger steak one with mashed potatoes the other with eggs and grits. Both came to table 22 min later COLD. Everything on both plates. Told server she took both meals back. Another 9 minute wait for food to be brought back. The hamburger patties looked microwaved on plate sitting in puddles of grease. Not to mention they brought back wrong sides for BOTH of us. We took a couple bites asked for bill and paid full price for meals we didn't eat. It's not about the money by any means just about a terrible experience from one of my go to places.
#    BUSINESS CATEGORY: American restaurant, Gift shop, Hobby store, Restaurant, Southern restaurant (US)
#    RATING: 2
#    CURRENT LABEL: Low quality review
#    HAS BUSINESS RESPONSE: True
#    CONFIDENCE: High
#    REASONING: Content not related to business type (American restaurant, Gift shop, Hobby store, Restaurant, Southern restaurant (US))
# ------------------------------------------------------------
#
# 3. EXAMPLE:
#    TEXT: In the medical department there is person whom goes by the name VICKI. Be sure to have your cellphones on and record whatever she speaks with you about because her story of what she tells you tends to change on a routine basis. I've had to bring back signed documents in order to continue donating and it was brought to my attention by other employees that work in medical that she misplaced a couple of my signed documents several times. This caused my clearance to continue donating to be delayed for 13 weeks the first time she did this and somehow 7 more weeks the second time. The doctor whom reviews the documents to see if you're cleared was not able to view mine due to VICKI FILING MY SIGNED DOCUMENTS TO THE WRONG PLACE AND AGAIN THIS HAPPENED TWICE BY HER. SHE TAKES MEDICATION THAT HELPS PREVENT SLEEP ATTACKS AT WORK ETC. I've seen her nod off to sleep while talking to me and she explained this because she was nodding off to sleep several times right in front of me. MIND YOU SHE WAS DOING THIS WHILE TYPING ON HER COMPUTER! I understand having a medical problem but if you can't do your job due to this medical problem then its best you return to your doctor for an alternative or perhaps YOU NEED TO FIND ANOTHER JOB BESIDES MISPLACING DONORS MEDICAL FILES! I doubt the F.D.A. WOULD APPROVE OF SUCH PRACTICES ON YOUR JOB.
#    BUSINESS CATEGORY: Blood donation center
#    RATING: 1
#    CURRENT LABEL: Low quality review
#    HAS BUSINESS RESPONSE: False
#    CONFIDENCE: High
#    REASONING: Content not related to business type (Blood donation center)
# ------------------------------------------------------------
#
# 4. EXAMPLE:
#    TEXT: Finally decided to go back to a different location. Food was pretty good and the guacamole was fresh and green.
#    BUSINESS CATEGORY: Mexican restaurant, Caterer, Fast food restaurant
#    RATING: 4
#    CURRENT LABEL: Low quality review
#    HAS BUSINESS RESPONSE: False
#    CONFIDENCE: High
#    REASONING: Content not related to business type (Mexican restaurant, Caterer, Fast food restaurant)
# ------------------------------------------------------------
#
# 5. EXAMPLE:
#    TEXT: Not a member, but this whole time I thought this was such a waste of rent, but with Gold's being a colossal failure and leaving their members hanging I suddenly see how genius this was. Lol.
#    BUSINESS CATEGORY: Gym, Fitness center, Indoor cycling, Personal trainer
#    RATING: 5
#    CURRENT LABEL: Acceptable review
#    HAS BUSINESS RESPONSE: False
#    CONFIDENCE: High
#    REASONING: Content not related to business type (Gym, Fitness center, Indoor cycling, Personal trainer)
# ------------------------------------------------------------
#
# ============================================================
# SUGGESTED LABEL: ADVERTISEMENT
# ============================================================
# Found 0 examples
# No examples found for this category
#
# ============================================================
# SUMMARY OF SUGGESTED LABELS
# ============================================================
# Acceptable review        :  10 examples found
# Low quality review       :  10 examples found
# Rant without visit       :   2 examples found
# Irrelevant content       :   5 examples found
# Advertisement            :   0 examples found
# Total examples           :  27
